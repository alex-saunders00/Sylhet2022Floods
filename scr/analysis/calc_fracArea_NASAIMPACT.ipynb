# %% [markdown]
# # Project: NIP
# # Subroject: Sylhet Floods, June 2022
# ## Script: calc_fracArea_NASAIMPACT.ipynb
# This script generates a time series of the fractional inundated area, from the outputs of the NASA IMPACT ML Sentinel-1 surface water mapping algorithm.

# %%
from pathlib import Path
import os
import sys
import pandas as pd
import numpy as np
import rasterio
import matplotlib.pyplot as plt
from rasterio.plot import show
from rasterio.mask import mask
from itertools import chain
from pyproj import Transformer
from matplotlib.patches import Patch
from matplotlib.colors import ListedColormap
import matplotlib.colors as colors
from datetime import datetime
import geopandas as gpd
import copy
import collections
from shapely.geometry import mapping
import pycrs
from shapely.geometry import Polygon
from functools import reduce
import shutil

# %%
# Set the root path
rootPath = Path('Z:/media/mule/Projects/NASA/NIP/Data')

# %%
# Add path for the Helpers modules
module_path = os.path.abspath(os.path.join('C:/Users/alexsaunders/Documents/01_uoa/04_git/NIP/Sylhet/'))
if module_path not in sys.path:
    sys.path.append(module_path)

# %%
# Import module from analyse_modifiedDevries containing helpful functions to use
import importlib
import Helpers.analyse_modifiedDevries as analyse_DV
importlib.reload(analyse_DV)
# Out:
# <module 'Helpers.analyse_modifiedDevries' from 'C:\\Users\\alexsaunders\\Documents\\01_uoa\\04_git\\NIP\\Sylhet\\Helpers\\analyse_modifiedDevries.py'>

# %% [markdown]
# ## PART 1: Define the ROI(s) for computing fractional flooded area
# Load in the admin areas and gauge locations, create some buffer sizes around the gauges to use as ROI for computing FFA

# %%
# Move the mosaic NASSA IMPACT predictions to a single folder
dataPath = rootPath/'Raster/SylhetNASAImpact/5_Preds'

# %%
dataDatePaths = list(dataPath.iterdir())[:-1]

# %%
mosaicPath=dataPath/'Mosaic/v2'
mosaicPath.mkdir(exist_ok=True)

# %%
# for dataDatePath in dataDatePaths:
#     mosaicFile=list((dataDatePath/'Mosaic').iterdir())[0]
#     #Make a copy in the central Mosaic folder and delete original file
#     filename=mosaicFile.stem+mosaicFile.suffix
#     shutil.copy(mosaicFile, mosaicPath/filename)
#     # os.remove(mosaicFile)

# %%
mosaics = [file for file in mosaicPath.iterdir() if file.is_file() and '2022' in str(file) and file.suffix == '.tif']
mosaics
# Out:
# [WindowsPath('Z:/media/mule/Projects/NASA/NIP/Data/Raster/SylhetNASAImpact/5_Preds/Mosaic/v2/20220501.tif'),
#  WindowsPath('Z:/media/mule/Projects/NASA/NIP/Data/Raster/SylhetNASAImpact/5_Preds/Mosaic/v2/20220511.tif'),
#  WindowsPath('Z:/media/mule/Projects/NASA/NIP/Data/Raster/SylhetNASAImpact/5_Preds/Mosaic/v2/20220513.tif'),
#  WindowsPath('Z:/media/mule/Projects/NASA/NIP/Data/Raster/SylhetNASAImpact/5_Preds/Mosaic/v2/20220523.tif'),
#  WindowsPath('Z:/media/mule/Projects/NASA/NIP/Data/Raster/SylhetNASAImpact/5_Preds/Mosaic/v2/20220525.tif'),
#  WindowsPath('Z:/media/mule/Projects/NASA/NIP/Data/Raster/SylhetNASAImpact/5_Preds/Mosaic/v2/20220604.tif'),
#  WindowsPath('Z:/media/mule/Projects/NASA/NIP/Data/Raster/SylhetNASAImpact/5_Preds/Mosaic/v2/20220606.tif'),
#  WindowsPath('Z:/media/mule/Projects/NASA/NIP/Data/Raster/SylhetNASAImpact/5_Preds/Mosaic/v2/20220616.tif'),
#  WindowsPath('Z:/media/mule/Projects/NASA/NIP/Data/Raster/SylhetNASAImpact/5_Preds/Mosaic/v2/20220618.tif'),
#  WindowsPath('Z:/media/mule/Projects/NASA/NIP/Data/Raster/SylhetNASAImpact/5_Preds/Mosaic/v2/20220628.tif'),
#  WindowsPath('Z:/media/mule/Projects/NASA/NIP/Data/Raster/SylhetNASAImpact/5_Preds/Mosaic/v2/20220630.tif'),
#  WindowsPath('Z:/media/mule/Projects/NASA/NIP/Data/Raster/SylhetNASAImpact/5_Preds/Mosaic/v2/20220712.tif'),
#  WindowsPath('Z:/media/mule/Projects/NASA/NIP/Data/Raster/SylhetNASAImpact/5_Preds/Mosaic/v2/20220722.tif'),
#  WindowsPath('Z:/media/mule/Projects/NASA/NIP/Data/Raster/SylhetNASAImpact/5_Preds/Mosaic/v2/20220724.tif'),
#  WindowsPath('Z:/media/mule/Projects/NASA/NIP/Data/Raster/SylhetNASAImpact/5_Preds/Mosaic/v2/20220803.tif'),
#  WindowsPath('Z:/media/mule/Projects/NASA/NIP/Data/Raster/SylhetNASAImpact/5_Preds/Mosaic/v2/20220805.tif'),
#  WindowsPath('Z:/media/mule/Projects/NASA/NIP/Data/Raster/SylhetNASAImpact/5_Preds/Mosaic/v2/20220815.tif'),
#  WindowsPath('Z:/media/mule/Projects/NASA/NIP/Data/Raster/SylhetNASAImpact/5_Preds/Mosaic/v2/20220827.tif'),
#  WindowsPath('Z:/media/mule/Projects/NASA/NIP/Data/Raster/SylhetNASAImpact/5_Preds/Mosaic/v2/20220829.tif')]

# %%
# Import the ROI geometry from shapefile
adminShapePath = rootPath/'Shapefiles/AdminHDX'
districts = gpd.read_file(adminShapePath/'bgd_admbnda_adm2_bbs_20201113.shp')
upazillas = gpd.read_file(adminShapePath/'bgd_admbnda_adm3_bbs_20201113.shp')
sylhet_dist = districts[districts['ADM2_EN']=='Sylhet']
sylhet_upa = upazillas[upazillas['ADM3_EN']=='Sylhet Sadar']

# %%
# Or instead create the ROI as a buffer around the gauge locations

# Import the gauge station locations
gaugePath = rootPath/'Stream_Gauge/StreamGaugeShapefiles'
gaugeLocs = gpd.read_file(gaugePath/'streamgaugew_division.shp') # read the file as a geopandas

# Create buffer around all gauges - use several different buffer sizes starting from 100 m, to 1 km
gaugeLocsGeoms = gaugeLocs.geometry
buffer_sizes = [5, 10, 15]#[0.1, 0.2, 0.5, 1]
pd.options.mode.chained_assignment = None  # default='warn'

for buffer_size in buffer_sizes:
    
    # Add new field to locs geodataframe to store the buffer geometries
    gaugeLocs['buffer_'+str(buffer_size)] = 0

    # For each gaugeLoc, get the buffer and add back to the geodataframe
    for i in range(0, len(gaugeLocs)):
        gaugeLocGeom = gaugeLocsGeoms[i]
        buffer = analyse_DV.geodesic_point_buffer(gaugeLocGeom.y, gaugeLocGeom.x, buffer_size) # lat, lon, buffer (in km)
        gaugeLocs['buffer_'+str(buffer_size)][i] = Polygon(buffer)

# %%
# Define the gauges in Sylhet District
streamGaugeDataPath = rootPath/'Stream_Gauge/'
gauges_in_sylhet = pd.read_csv(streamGaugeDataPath/'streamgauges_SylhetDist.csv', header=0)
gauges_in_sylhet = list(gauges_in_sylhet['streamvect'])
gaugeDataSummaryMaster = pd.read_csv(streamGaugeDataPath/'CombinedAll2004-2022/Combined/summary.csv', header=0)
gauges = [match for match in gauges_in_sylhet if match in list(gaugeDataSummaryMaster['stationID'][np.logical_and(~np.isnan(gaugeDataSummaryMaster['danger_level']),gaugeDataSummaryMaster['danger_level']<1000)])]
print(gauges)
gauges_in_sylhet_geom = gaugeLocs[gaugeLocs['streamvect'].isin(gauges_in_sylhet)]
gauges_geom = gaugeLocs[gaugeLocs['streamvect'].isin(gauges)]
# Out:
# ['SW172.5', 'SW173', 'SW175.5', 'SW251', 'SW266', 'SW267']

# %%
gauges_list = list(chain.from_iterable([list(gauges_geom['streamvect']+'_'+str(buffer_size)+'km') for buffer_size in buffer_sizes]))
gauges_geom_list = list(chain.from_iterable([list(gauges_geom['buffer_'+str(buffer_size)]) for buffer_size in buffer_sizes]))

# %%
# Create a single geodataframe of ROIs over which to calculate FFA
rois = {'id': ['Sylhet_District', 'Sylhet_Upazilla']+gauges_list, 
        'geometry': list(sylhet_dist.geometry)+list(sylhet_upa.geometry)+gauges_geom_list}
rois_gdf = gpd.GeoDataFrame(rois, geometry='geometry', crs='epsg:4326')

# %% [markdown]
# ## PART 2: Compute the fractional inundated area at each timestep
# For each date, extract the fractional inundated area for the specified ROI.

# %%
# Get the dates of images
dates = [str(datetime.strptime(mosaic.stem, '%Y%m%d').date()) for mosaic in mosaics]
print(dates)
# Out:
# ['2022-05-01', '2022-05-11', '2022-05-13', '2022-05-23', '2022-05-25', '2022-06-04', '2022-06-06', '2022-06-16', '2022-06-18', '2022-06-28', '2022-06-30', '2022-07-12', '2022-07-22', '2022-07-24', '2022-08-03', '2022-08-05', '2022-08-15', '2022-08-27', '2022-08-29']

# %%
# Run the function to create temp raster file for using in masking - ONLY NEEDS TO BE RUN ONCE

#Run the function which creates a raster of values 10, the same dimensions as the flood raster, to be used for clipping to the ROI later
# date1 = '20220604'
# mosaic = [mosaic for mosaic in mosaics if date1 in str(mosaic)][0]
analyse_DV.create_temp_raster_for_mask(mosaics[0], rootPath, mosaicPath) #'Raster/SylhetNASAImpact/5_Preds/Mosaic') # creates raster_tmp

# %%
# Load the temp raster in and intersect it with the ROI - this will be used for clipping to the ROI since it contains values of 10
# raster_tmp = rasterio.open(rootPath/'Raster/Sylhet/Sen1MitchellSingleOrbit/Mosaic'/'temp.tif') # can recreate this file if needs for a different ROI area by rerunning the above function
raster_tmp = rasterio.open(mosaicPath/'temp.tif') # can recreate this file if needs for a different ROI area by rerunning the above function

# %%
# Run the function to get the fractional flooded area for all image dates, for all the provided ROIs
mosaic_dates = []
pctWaters = []
rois_list = []

# Loop through image dates
for n, mosaic in enumerate(mosaics):
    
    # Get the date
    mosaic_date = str(datetime.strptime(mosaic.stem, '%Y%m%d').date())
    print('Mosaic:', mosaic_date, mosaic)

#     # Load the raster using rioxarray
#     raster = prep_raster.load_raster_for_comparison(mosaic, -10)

#     # Reproject and match the GFM raster to the modified Devries raster to make the processing the same
#     raster_reproj = prep_raster.reproj_match_raster(raster, raster_Devries)
    
    # Load the raster
    with rasterio.open(mosaic) as file:
        raster = file.read(1)

    # Set the water values to 1
    water = copy.copy(raster)
    water[water==1]=1
    
    # Loop through all ROI geometries
    for j in range(len(rois_gdf)):

        # Run the function to create the raster mask for the ROI, using the temp raster containing all values 10
        roiID = rois_gdf.id[j]
        roi = rois_gdf.loc[[j]]
        roi_mask = analyse_DV.create_roi_mask(raster_tmp, roi)

        # Apply the mask to the water_sum raster by performing an array sum operation
        water_roi = np.add(water, roi_mask)

        # Get the number of pixels of water for each date for the ROI only (pixel values in ROI have been shifted by +10 from original values)
        water_roi_vals = list(chain.from_iterable(water_roi.tolist()))
        counter_roi = collections.Counter(water_roi_vals) # 10 = none, 11 = water, other = invalid or outside ROI
        pctWater_roi = counter_roi[11] / (counter_roi[10] + counter_roi[11])
        #print(counter_roi)
        print('ROI % water at {0} for {1}: {2:2.1f}%'.format(mosaic_date, roiID, pctWater_roi*100))
        
        # Record the results for the date and ROI
        mosaic_dates.append(mosaic_date)
        rois_list.append(roiID)
        pctWaters.append(pctWater_roi)
# Out:
# Mosaic: 2022-05-01 Z:\media\mule\Projects\NASA\NIP\Data\Raster\SylhetNASAImpact\5_Preds\Mosaic\v2\20220501.tif
# ROI % water at 2022-05-01 for Sylhet_District: 4.5%
# ROI % water at 2022-05-01 for Sylhet_Upazilla: 2.4%
# ROI % water at 2022-05-01 for SW172.5_5km: 3.5%
# ROI % water at 2022-05-01 for SW173_5km: 4.6%
# ROI % water at 2022-05-01 for SW175.5_5km: 5.2%
# ROI % water at 2022-05-01 for SW251_5km: 2.4%
# ROI % water at 2022-05-01 for SW266_5km: 3.8%
# ROI % water at 2022-05-01 for SW267_5km: 2.3%
# ROI % water at 2022-05-01 for SW172.5_10km: 3.9%
# ROI % water at 2022-05-01 for SW173_10km: 3.9%
# ROI % water at 2022-05-01 for SW175.5_10km: 4.3%
# ROI % water at 2022-05-01 for SW251_10km: 3.5%
# ROI % water at 2022-05-01 for SW266_10km: 3.6%
# ROI % water at 2022-05-01 for SW267_10km: 1.8%
# ROI % water at 2022-05-01 for SW172.5_15km: 3.7%
# ROI % water at 2022-05-01 for SW173_15km: 4.4%
# ROI % water at 2022-05-01 for SW175.5_15km: 3.4%
# ROI % water at 2022-05-01 for SW251_15km: 4.3%
# ROI % water at 2022-05-01 for SW266_15km: 3.4%
# ROI % water at 2022-05-01 for SW267_15km: 2.0%
# Mosaic: 2022-05-11 Z:\media\mule\Projects\NASA\NIP\Data\Raster\SylhetNASAImpact\5_Preds\Mosaic\v2\20220511.tif
# ROI % water at 2022-05-11 for Sylhet_District: 15.0%
# ROI % water at 2022-05-11 for Sylhet_Upazilla: 10.9%
# ROI % water at 2022-05-11 for SW172.5_5km: 20.9%
# ROI % water at 2022-05-11 for SW173_5km: 10.2%
# ROI % water at 2022-05-11 for SW175.5_5km: 8.2%
# ROI % water at 2022-05-11 for SW251_5km: 9.2%
# ROI % water at 2022-05-11 for SW266_5km: 3.4%
# ROI % water at 2022-05-11 for SW267_5km: 9.8%
# ROI % water at 2022-05-11 for SW172.5_10km: 24.2%
# ROI % water at 2022-05-11 for SW173_10km: 12.2%
# ROI % water at 2022-05-11 for SW175.5_10km: 6.9%
# ROI % water at 2022-05-11 for SW251_10km: 11.5%
# ROI % water at 2022-05-11 for SW266_10km: 7.4%
# ROI % water at 2022-05-11 for SW267_10km: 15.6%
# ROI % water at 2022-05-11 for SW172.5_15km: 21.6%
# ROI % water at 2022-05-11 for SW173_15km: 12.7%
# ROI % water at 2022-05-11 for SW175.5_15km: 5.7%
# ROI % water at 2022-05-11 for SW251_15km: 12.9%
# ROI % water at 2022-05-11 for SW266_15km: 10.7%
# ROI % water at 2022-05-11 for SW267_15km: 17.0%
# Mosaic: 2022-05-13 Z:\media\mule\Projects\NASA\NIP\Data\Raster\SylhetNASAImpact\5_Preds\Mosaic\v2\20220513.tif
# ROI % water at 2022-05-13 for Sylhet_District: 45.5%
# ROI % water at 2022-05-13 for Sylhet_Upazilla: 31.1%
# ROI % water at 2022-05-13 for SW172.5_5km: 26.7%
# ROI % water at 2022-05-13 for SW173_5km: 34.5%
# ROI % water at 2022-05-13 for SW175.5_5km: 15.8%
# ROI % water at 2022-05-13 for SW251_5km: 49.5%
# ROI % water at 2022-05-13 for SW266_5km: 55.2%
# ROI % water at 2022-05-13 for SW267_5km: 12.5%
# ROI % water at 2022-05-13 for SW172.5_10km: 37.1%
# ROI % water at 2022-05-13 for SW173_10km: 35.5%
# ROI % water at 2022-05-13 for SW175.5_10km: 20.2%
# ROI % water at 2022-05-13 for SW251_10km: 52.2%
# ROI % water at 2022-05-13 for SW266_10km: 55.1%
# ROI % water at 2022-05-13 for SW267_10km: 26.8%
# ROI % water at 2022-05-13 for SW172.5_15km: 36.0%
# ROI % water at 2022-05-13 for SW173_15km: 38.7%
# ROI % water at 2022-05-13 for SW175.5_15km: 21.6%
# ROI % water at 2022-05-13 for SW251_15km: 49.4%
# ROI % water at 2022-05-13 for SW266_15km: 44.5%
# ROI % water at 2022-05-13 for SW267_15km: 34.4%
# Mosaic: 2022-05-23 Z:\media\mule\Projects\NASA\NIP\Data\Raster\SylhetNASAImpact\5_Preds\Mosaic\v2\20220523.tif
# ROI % water at 2022-05-23 for Sylhet_District: 58.6%
# ROI % water at 2022-05-23 for Sylhet_Upazilla: 44.5%
# ROI % water at 2022-05-23 for SW172.5_5km: 28.6%
# ROI % water at 2022-05-23 for SW173_5km: 61.4%
# ROI % water at 2022-05-23 for SW175.5_5km: 52.8%
# ROI % water at 2022-05-23 for SW251_5km: 35.8%
# ROI % water at 2022-05-23 for SW266_5km: 63.9%
# ROI % water at 2022-05-23 for SW267_5km: 15.7%
# ROI % water at 2022-05-23 for SW172.5_10km: 40.3%
# ROI % water at 2022-05-23 for SW173_10km: 56.3%
# ROI % water at 2022-05-23 for SW175.5_10km: 56.4%
# ROI % water at 2022-05-23 for SW251_10km: 50.4%
# ROI % water at 2022-05-23 for SW266_10km: 62.0%
# ROI % water at 2022-05-23 for SW267_10km: 35.1%
# ROI % water at 2022-05-23 for SW172.5_15km: 45.5%
# ROI % water at 2022-05-23 for SW173_15km: 55.1%
# ROI % water at 2022-05-23 for SW175.5_15km: 54.5%
# ROI % water at 2022-05-23 for SW251_15km: 52.3%
# ROI % water at 2022-05-23 for SW266_15km: 49.9%
# ROI % water at 2022-05-23 for SW267_15km: 45.2%
# Mosaic: 2022-05-25 Z:\media\mule\Projects\NASA\NIP\Data\Raster\SylhetNASAImpact\5_Preds\Mosaic\v2\20220525.tif
# ROI % water at 2022-05-25 for Sylhet_District: 53.1%
# ROI % water at 2022-05-25 for Sylhet_Upazilla: 39.5%
# ROI % water at 2022-05-25 for SW172.5_5km: 16.5%
# ROI % water at 2022-05-25 for SW173_5km: 54.9%
# ROI % water at 2022-05-25 for SW175.5_5km: 48.5%
# ROI % water at 2022-05-25 for SW251_5km: 24.0%
# ROI % water at 2022-05-25 for SW266_5km: 48.6%
# ROI % water at 2022-05-25 for SW267_5km: 11.4%
# ROI % water at 2022-05-25 for SW172.5_10km: 29.4%
# ROI % water at 2022-05-25 for SW173_10km: 49.0%
# ROI % water at 2022-05-25 for SW175.5_10km: 53.7%
# ROI % water at 2022-05-25 for SW251_10km: 43.3%
# ROI % water at 2022-05-25 for SW266_10km: 52.5%
# ROI % water at 2022-05-25 for SW267_10km: 29.3%
# ROI % water at 2022-05-25 for SW172.5_15km: 37.2%
# ROI % water at 2022-05-25 for SW173_15km: 49.1%
# ROI % water at 2022-05-25 for SW175.5_15km: 51.9%
# ROI % water at 2022-05-25 for SW251_15km: 45.9%
# ROI % water at 2022-05-25 for SW266_15km: 43.3%
# ROI % water at 2022-05-25 for SW267_15km: 39.6%
# Mosaic: 2022-06-04 Z:\media\mule\Projects\NASA\NIP\Data\Raster\SylhetNASAImpact\5_Preds\Mosaic\v2\20220604.tif
# ROI % water at 2022-06-04 for Sylhet_District: 50.1%
# ROI % water at 2022-06-04 for Sylhet_Upazilla: 33.6%
# ROI % water at 2022-06-04 for SW172.5_5km: 21.5%
# ROI % water at 2022-06-04 for SW173_5km: 48.7%
# ROI % water at 2022-06-04 for SW175.5_5km: 52.4%
# ROI % water at 2022-06-04 for SW251_5km: 34.7%
# ROI % water at 2022-06-04 for SW266_5km: 48.8%
# ROI % water at 2022-06-04 for SW267_5km: 7.5%
# ROI % water at 2022-06-04 for SW172.5_10km: 33.1%
# ROI % water at 2022-06-04 for SW173_10km: 43.2%
# ROI % water at 2022-06-04 for SW175.5_10km: 53.6%
# ROI % water at 2022-06-04 for SW251_10km: 48.4%
# ROI % water at 2022-06-04 for SW266_10km: 51.5%
# ROI % water at 2022-06-04 for SW267_10km: 22.0%
# ROI % water at 2022-06-04 for SW172.5_15km: 38.9%
# ROI % water at 2022-06-04 for SW173_15km: 44.2%
# ROI % water at 2022-06-04 for SW175.5_15km: 50.8%
# ROI % water at 2022-06-04 for SW251_15km: 48.8%
# ROI % water at 2022-06-04 for SW266_15km: 42.0%
# ROI % water at 2022-06-04 for SW267_15km: 33.5%
# Mosaic: 2022-06-06 Z:\media\mule\Projects\NASA\NIP\Data\Raster\SylhetNASAImpact\5_Preds\Mosaic\v2\20220606.tif
# ROI % water at 2022-06-06 for Sylhet_District: 55.4%
# ROI % water at 2022-06-06 for Sylhet_Upazilla: 43.7%
# ROI % water at 2022-06-06 for SW172.5_5km: 18.9%
# ROI % water at 2022-06-06 for SW173_5km: 52.3%
# ROI % water at 2022-06-06 for SW175.5_5km: 50.4%
# ROI % water at 2022-06-06 for SW251_5km: 46.1%
# ROI % water at 2022-06-06 for SW266_5km: 61.3%
# ROI % water at 2022-06-06 for SW267_5km: 12.1%
# ROI % water at 2022-06-06 for SW172.5_10km: 34.1%
# ROI % water at 2022-06-06 for SW173_10km: 48.6%
# ROI % water at 2022-06-06 for SW175.5_10km: 53.5%
# ROI % water at 2022-06-06 for SW251_10km: 55.5%
# ROI % water at 2022-06-06 for SW266_10km: 60.6%
# ROI % water at 2022-06-06 for SW267_10km: 30.6%
# ROI % water at 2022-06-06 for SW172.5_15km: 41.1%
# ROI % water at 2022-06-06 for SW173_15km: 48.5%
# ROI % water at 2022-06-06 for SW175.5_15km: 51.9%
# ROI % water at 2022-06-06 for SW251_15km: 54.7%
# ROI % water at 2022-06-06 for SW266_15km: 48.2%
# ROI % water at 2022-06-06 for SW267_15km: 42.6%
# Mosaic: 2022-06-16 Z:\media\mule\Projects\NASA\NIP\Data\Raster\SylhetNASAImpact\5_Preds\Mosaic\v2\20220616.tif
# ROI % water at 2022-06-16 for Sylhet_District: 52.4%
# ROI % water at 2022-06-16 for Sylhet_Upazilla: 46.6%
# ROI % water at 2022-06-16 for SW172.5_5km: 20.0%
# ROI % water at 2022-06-16 for SW173_5km: 50.1%
# ROI % water at 2022-06-16 for SW175.5_5km: 47.6%
# ROI % water at 2022-06-16 for SW251_5km: 51.9%
# ROI % water at 2022-06-16 for SW266_5km: 62.0%
# ROI % water at 2022-06-16 for SW267_5km: 9.3%
# ROI % water at 2022-06-16 for SW172.5_10km: 33.2%
# ROI % water at 2022-06-16 for SW173_10km: 46.9%
# ROI % water at 2022-06-16 for SW175.5_10km: 51.5%
# ROI % water at 2022-06-16 for SW251_10km: 54.6%
# ROI % water at 2022-06-16 for SW266_10km: 62.6%
# ROI % water at 2022-06-16 for SW267_10km: 31.1%
# ROI % water at 2022-06-16 for SW172.5_15km: 40.5%
# ROI % water at 2022-06-16 for SW173_15km: 46.2%
# ROI % water at 2022-06-16 for SW175.5_15km: 50.0%
# ROI % water at 2022-06-16 for SW251_15km: 54.0%
# ROI % water at 2022-06-16 for SW266_15km: 48.8%
# ROI % water at 2022-06-16 for SW267_15km: 41.3%
# Mosaic: 2022-06-18 Z:\media\mule\Projects\NASA\NIP\Data\Raster\SylhetNASAImpact\5_Preds\Mosaic\v2\20220618.tif
# ROI % water at 2022-06-18 for Sylhet_District: 62.7%
# ROI % water at 2022-06-18 for Sylhet_Upazilla: 47.3%
# ROI % water at 2022-06-18 for SW172.5_5km: 23.4%
# ROI % water at 2022-06-18 for SW173_5km: 59.3%
# ROI % water at 2022-06-18 for SW175.5_5km: 59.7%
# ROI % water at 2022-06-18 for SW251_5km: 60.6%
# ROI % water at 2022-06-18 for SW266_5km: 68.2%
# ROI % water at 2022-06-18 for SW267_5km: 19.9%
# ROI % water at 2022-06-18 for SW172.5_10km: 33.3%
# ROI % water at 2022-06-18 for SW173_10km: 57.1%
# ROI % water at 2022-06-18 for SW175.5_10km: 61.4%
# ROI % water at 2022-06-18 for SW251_10km: 62.3%
# ROI % water at 2022-06-18 for SW266_10km: 64.0%
# ROI % water at 2022-06-18 for SW267_10km: 40.4%
# ROI % water at 2022-06-18 for SW172.5_15km: 38.7%
# ROI % water at 2022-06-18 for SW173_15km: 57.0%
# ROI % water at 2022-06-18 for SW175.5_15km: 60.5%
# ROI % water at 2022-06-18 for SW251_15km: 59.8%
# ROI % water at 2022-06-18 for SW266_15km: 51.4%
# ROI % water at 2022-06-18 for SW267_15km: 50.9%
# Mosaic: 2022-06-28 Z:\media\mule\Projects\NASA\NIP\Data\Raster\SylhetNASAImpact\5_Preds\Mosaic\v2\20220628.tif
# ROI % water at 2022-06-28 for Sylhet_District: 61.4%
# ROI % water at 2022-06-28 for Sylhet_Upazilla: 43.8%
# ROI % water at 2022-06-28 for SW172.5_5km: 34.2%
# ROI % water at 2022-06-28 for SW173_5km: 67.0%
# ROI % water at 2022-06-28 for SW175.5_5km: 59.2%
# ROI % water at 2022-06-28 for SW251_5km: 40.6%
# ROI % water at 2022-06-28 for SW266_5km: 67.0%
# ROI % water at 2022-06-28 for SW267_5km: 15.9%
# ROI % water at 2022-06-28 for SW172.5_10km: 47.9%
# ROI % water at 2022-06-28 for SW173_10km: 60.6%
# ROI % water at 2022-06-28 for SW175.5_10km: 61.9%
# ROI % water at 2022-06-28 for SW251_10km: 54.1%
# ROI % water at 2022-06-28 for SW266_10km: 63.9%
# ROI % water at 2022-06-28 for SW267_10km: 36.9%
# ROI % water at 2022-06-28 for SW172.5_15km: 52.1%
# ROI % water at 2022-06-28 for SW173_15km: 58.7%
# ROI % water at 2022-06-28 for SW175.5_15km: 61.7%
# ROI % water at 2022-06-28 for SW251_15km: 54.8%
# ROI % water at 2022-06-28 for SW266_15km: 52.4%
# ROI % water at 2022-06-28 for SW267_15km: 48.3%
# Mosaic: 2022-06-30 Z:\media\mule\Projects\NASA\NIP\Data\Raster\SylhetNASAImpact\5_Preds\Mosaic\v2\20220630.tif
# ROI % water at 2022-06-30 for Sylhet_District: 61.2%
# ROI % water at 2022-06-30 for Sylhet_Upazilla: 44.8%
# ROI % water at 2022-06-30 for SW172.5_5km: 35.7%
# ROI % water at 2022-06-30 for SW173_5km: 67.1%
# ROI % water at 2022-06-30 for SW175.5_5km: 53.3%
# ROI % water at 2022-06-30 for SW251_5km: 46.9%
# ROI % water at 2022-06-30 for SW266_5km: 67.5%
# ROI % water at 2022-06-30 for SW267_5km: 13.6%
# ROI % water at 2022-06-30 for SW172.5_10km: 47.7%
# ROI % water at 2022-06-30 for SW173_10km: 61.4%
# ROI % water at 2022-06-30 for SW175.5_10km: 58.0%
# ROI % water at 2022-06-30 for SW251_10km: 56.4%
# ROI % water at 2022-06-30 for SW266_10km: 64.8%
# ROI % water at 2022-06-30 for SW267_10km: 36.2%
# ROI % water at 2022-06-30 for SW172.5_15km: 51.7%
# ROI % water at 2022-06-30 for SW173_15km: 59.1%
# ROI % water at 2022-06-30 for SW175.5_15km: 58.0%
# ROI % water at 2022-06-30 for SW251_15km: 56.2%
# ROI % water at 2022-06-30 for SW266_15km: 52.8%
# ROI % water at 2022-06-30 for SW267_15km: 47.5%
# Mosaic: 2022-07-12 Z:\media\mule\Projects\NASA\NIP\Data\Raster\SylhetNASAImpact\5_Preds\Mosaic\v2\20220712.tif
# ROI % water at 2022-07-12 for Sylhet_District: 50.8%
# ROI % water at 2022-07-12 for Sylhet_Upazilla: 32.6%
# ROI % water at 2022-07-12 for SW172.5_5km: 29.5%
# ROI % water at 2022-07-12 for SW173_5km: 62.8%
# ROI % water at 2022-07-12 for SW175.5_5km: 43.7%
# ROI % water at 2022-07-12 for SW251_5km: 20.8%
# ROI % water at 2022-07-12 for SW266_5km: 59.5%
# ROI % water at 2022-07-12 for SW267_5km: 10.1%
# ROI % water at 2022-07-12 for SW172.5_10km: 43.3%
# ROI % water at 2022-07-12 for SW173_10km: 54.1%
# ROI % water at 2022-07-12 for SW175.5_10km: 51.4%
# ROI % water at 2022-07-12 for SW251_10km: 39.6%
# ROI % water at 2022-07-12 for SW266_10km: 56.7%
# ROI % water at 2022-07-12 for SW267_10km: 24.1%
# ROI % water at 2022-07-12 for SW172.5_15km: 47.6%
# ROI % water at 2022-07-12 for SW173_15km: 52.9%
# ROI % water at 2022-07-12 for SW175.5_15km: 51.0%
# ROI % water at 2022-07-12 for SW251_15km: 43.3%
# ROI % water at 2022-07-12 for SW266_15km: 46.3%
# ROI % water at 2022-07-12 for SW267_15km: 35.2%
# Mosaic: 2022-07-22 Z:\media\mule\Projects\NASA\NIP\Data\Raster\SylhetNASAImpact\5_Preds\Mosaic\v2\20220722.tif
# ROI % water at 2022-07-22 for Sylhet_District: 42.1%
# ROI % water at 2022-07-22 for Sylhet_Upazilla: 30.4%
# ROI % water at 2022-07-22 for SW172.5_5km: 13.5%
# ROI % water at 2022-07-22 for SW173_5km: 55.9%
# ROI % water at 2022-07-22 for SW175.5_5km: 43.3%
# ROI % water at 2022-07-22 for SW251_5km: 9.7%
# ROI % water at 2022-07-22 for SW266_5km: 32.8%
# ROI % water at 2022-07-22 for SW267_5km: 7.9%
# ROI % water at 2022-07-22 for SW172.5_10km: 27.8%
# ROI % water at 2022-07-22 for SW173_10km: 46.0%
# ROI % water at 2022-07-22 for SW175.5_10km: 49.4%
# ROI % water at 2022-07-22 for SW251_10km: 26.8%
# ROI % water at 2022-07-22 for SW266_10km: 37.8%
# ROI % water at 2022-07-22 for SW267_10km: 18.8%
# ROI % water at 2022-07-22 for SW172.5_15km: 35.6%
# ROI % water at 2022-07-22 for SW173_15km: 43.3%
# ROI % water at 2022-07-22 for SW175.5_15km: 48.1%
# ROI % water at 2022-07-22 for SW251_15km: 30.7%
# ROI % water at 2022-07-22 for SW266_15km: 32.6%
# ROI % water at 2022-07-22 for SW267_15km: 29.3%
# Mosaic: 2022-07-24 Z:\media\mule\Projects\NASA\NIP\Data\Raster\SylhetNASAImpact\5_Preds\Mosaic\v2\20220724.tif
# ROI % water at 2022-07-24 for Sylhet_District: 40.3%
# ROI % water at 2022-07-24 for Sylhet_Upazilla: 26.7%
# ROI % water at 2022-07-24 for SW172.5_5km: 24.0%
# ROI % water at 2022-07-24 for SW173_5km: 48.8%
# ROI % water at 2022-07-24 for SW175.5_5km: 41.1%
# ROI % water at 2022-07-24 for SW251_5km: 15.0%
# ROI % water at 2022-07-24 for SW266_5km: 31.6%
# ROI % water at 2022-07-24 for SW267_5km: 6.7%
# ROI % water at 2022-07-24 for SW172.5_10km: 32.5%
# ROI % water at 2022-07-24 for SW173_10km: 39.9%
# ROI % water at 2022-07-24 for SW175.5_10km: 47.8%
# ROI % water at 2022-07-24 for SW251_10km: 26.2%
# ROI % water at 2022-07-24 for SW266_10km: 34.8%
# ROI % water at 2022-07-24 for SW267_10km: 16.2%
# ROI % water at 2022-07-24 for SW172.5_15km: 37.8%
# ROI % water at 2022-07-24 for SW173_15km: 36.9%
# ROI % water at 2022-07-24 for SW175.5_15km: 45.6%
# ROI % water at 2022-07-24 for SW251_15km: 28.8%
# ROI % water at 2022-07-24 for SW266_15km: 29.6%
# ROI % water at 2022-07-24 for SW267_15km: 26.2%
# Mosaic: 2022-08-03 Z:\media\mule\Projects\NASA\NIP\Data\Raster\SylhetNASAImpact\5_Preds\Mosaic\v2\20220803.tif
# ROI % water at 2022-08-03 for Sylhet_District: 32.8%
# ROI % water at 2022-08-03 for Sylhet_Upazilla: 23.7%
# ROI % water at 2022-08-03 for SW172.5_5km: 15.8%
# ROI % water at 2022-08-03 for SW173_5km: 40.8%
# ROI % water at 2022-08-03 for SW175.5_5km: 37.1%
# ROI % water at 2022-08-03 for SW251_5km: 6.4%
# ROI % water at 2022-08-03 for SW266_5km: 24.8%
# ROI % water at 2022-08-03 for SW267_5km: 5.7%
# ROI % water at 2022-08-03 for SW172.5_10km: 30.1%
# ROI % water at 2022-08-03 for SW173_10km: 32.8%
# ROI % water at 2022-08-03 for SW175.5_10km: 43.5%
# ROI % water at 2022-08-03 for SW251_10km: 16.2%
# ROI % water at 2022-08-03 for SW266_10km: 30.4%
# ROI % water at 2022-08-03 for SW267_10km: 13.1%
# ROI % water at 2022-08-03 for SW172.5_15km: 36.6%
# ROI % water at 2022-08-03 for SW173_15km: 29.7%
# ROI % water at 2022-08-03 for SW175.5_15km: 41.0%
# ROI % water at 2022-08-03 for SW251_15km: 19.5%
# ROI % water at 2022-08-03 for SW266_15km: 25.4%
# ROI % water at 2022-08-03 for SW267_15km: 20.5%
# Mosaic: 2022-08-05 Z:\media\mule\Projects\NASA\NIP\Data\Raster\SylhetNASAImpact\5_Preds\Mosaic\v2\20220805.tif
# ROI % water at 2022-08-05 for Sylhet_District: 29.9%
# ROI % water at 2022-08-05 for Sylhet_Upazilla: 18.8%
# ROI % water at 2022-08-05 for SW172.5_5km: 15.2%
# ROI % water at 2022-08-05 for SW173_5km: 38.3%
# ROI % water at 2022-08-05 for SW175.5_5km: 44.6%
# ROI % water at 2022-08-05 for SW251_5km: 5.8%
# ROI % water at 2022-08-05 for SW266_5km: 20.7%
# ROI % water at 2022-08-05 for SW267_5km: 5.5%
# ROI % water at 2022-08-05 for SW172.5_10km: 26.6%
# ROI % water at 2022-08-05 for SW173_10km: 31.6%
# ROI % water at 2022-08-05 for SW175.5_10km: 49.1%
# ROI % water at 2022-08-05 for SW251_10km: 13.3%
# ROI % water at 2022-08-05 for SW266_10km: 26.7%
# ROI % water at 2022-08-05 for SW267_10km: 10.8%
# ROI % water at 2022-08-05 for SW172.5_15km: 32.1%
# ROI % water at 2022-08-05 for SW173_15km: 28.4%
# ROI % water at 2022-08-05 for SW175.5_15km: 44.0%
# ROI % water at 2022-08-05 for SW251_15km: 16.2%
# ROI % water at 2022-08-05 for SW266_15km: 22.3%
# ROI % water at 2022-08-05 for SW267_15km: 18.0%
# Mosaic: 2022-08-15 Z:\media\mule\Projects\NASA\NIP\Data\Raster\SylhetNASAImpact\5_Preds\Mosaic\v2\20220815.tif
# ROI % water at 2022-08-15 for Sylhet_District: 21.6%
# ROI % water at 2022-08-15 for Sylhet_Upazilla: 14.1%
# ROI % water at 2022-08-15 for SW172.5_5km: 7.3%
# ROI % water at 2022-08-15 for SW173_5km: 24.5%
# ROI % water at 2022-08-15 for SW175.5_5km: 36.5%
# ROI % water at 2022-08-15 for SW251_5km: 5.2%
# ROI % water at 2022-08-15 for SW266_5km: 13.0%
# ROI % water at 2022-08-15 for SW267_5km: 4.7%
# ROI % water at 2022-08-15 for SW172.5_10km: 11.2%
# ROI % water at 2022-08-15 for SW173_10km: 20.8%
# ROI % water at 2022-08-15 for SW175.5_10km: 40.7%
# ROI % water at 2022-08-15 for SW251_10km: 10.3%
# ROI % water at 2022-08-15 for SW266_10km: 16.9%
# ROI % water at 2022-08-15 for SW267_10km: 7.4%
# ROI % water at 2022-08-15 for SW172.5_15km: 16.5%
# ROI % water at 2022-08-15 for SW173_15km: 18.9%
# ROI % water at 2022-08-15 for SW175.5_15km: 37.2%
# ROI % water at 2022-08-15 for SW251_15km: 12.1%
# ROI % water at 2022-08-15 for SW266_15km: 13.4%
# ROI % water at 2022-08-15 for SW267_15km: 12.5%
# Mosaic: 2022-08-27 Z:\media\mule\Projects\NASA\NIP\Data\Raster\SylhetNASAImpact\5_Preds\Mosaic\v2\20220827.tif
# ROI % water at 2022-08-27 for Sylhet_District: 23.3%
# ROI % water at 2022-08-27 for Sylhet_Upazilla: 17.4%
# ROI % water at 2022-08-27 for SW172.5_5km: 4.4%
# ROI % water at 2022-08-27 for SW173_5km: 22.6%
# ROI % water at 2022-08-27 for SW175.5_5km: 28.9%
# ROI % water at 2022-08-27 for SW251_5km: 7.0%
# ROI % water at 2022-08-27 for SW266_5km: 15.8%
# ROI % water at 2022-08-27 for SW267_5km: 4.2%
# ROI % water at 2022-08-27 for SW172.5_10km: 9.7%
# ROI % water at 2022-08-27 for SW173_10km: 18.1%
# ROI % water at 2022-08-27 for SW175.5_10km: 37.0%
# ROI % water at 2022-08-27 for SW251_10km: 15.4%
# ROI % water at 2022-08-27 for SW266_10km: 19.2%
# ROI % water at 2022-08-27 for SW267_10km: 7.8%
# ROI % water at 2022-08-27 for SW172.5_15km: 12.0%
# ROI % water at 2022-08-27 for SW173_15km: 18.4%
# ROI % water at 2022-08-27 for SW175.5_15km: 35.8%
# ROI % water at 2022-08-27 for SW251_15km: 16.6%
# ROI % water at 2022-08-27 for SW266_15km: 15.7%
# ROI % water at 2022-08-27 for SW267_15km: 15.3%
# Mosaic: 2022-08-29 Z:\media\mule\Projects\NASA\NIP\Data\Raster\SylhetNASAImpact\5_Preds\Mosaic\v2\20220829.tif
# ROI % water at 2022-08-29 for Sylhet_District: 20.4%
# ROI % water at 2022-08-29 for Sylhet_Upazilla: 12.5%
# ROI % water at 2022-08-29 for SW172.5_5km: 4.6%
# ROI % water at 2022-08-29 for SW173_5km: 21.7%
# ROI % water at 2022-08-29 for SW175.5_5km: 26.6%
# ROI % water at 2022-08-29 for SW251_5km: 5.7%
# ROI % water at 2022-08-29 for SW266_5km: 12.7%
# ROI % water at 2022-08-29 for SW267_5km: 4.2%
# ROI % water at 2022-08-29 for SW172.5_10km: 8.2%
# ROI % water at 2022-08-29 for SW173_10km: 16.4%
# ROI % water at 2022-08-29 for SW175.5_10km: 33.3%
# ROI % water at 2022-08-29 for SW251_10km: 12.1%
# ROI % water at 2022-08-29 for SW266_10km: 16.0%
# ROI % water at 2022-08-29 for SW267_10km: 6.5%
# ROI % water at 2022-08-29 for SW172.5_15km: 10.2%
# ROI % water at 2022-08-29 for SW173_15km: 17.0%
# ROI % water at 2022-08-29 for SW175.5_15km: 31.3%
# ROI % water at 2022-08-29 for SW251_15km: 14.1%
# ROI % water at 2022-08-29 for SW266_15km: 12.9%
# ROI % water at 2022-08-29 for SW267_15km: 11.1%

# %%
# Create dataframe of the results - fractional flooded area
fracFloodArea = pd.DataFrame(data = [mosaic_dates, rois_list, pctWaters], index = ['Date','ROI','FFA']).T
fracFloodArea = fracFloodArea.pivot(index='Date', columns='ROI', values='FFA')
fracFloodArea.index = pd.to_datetime(fracFloodArea.index)

# %%
# Export the results as csv
outputPath = rootPath/'Table/SylhetFracFloodedArea'
outputPath.mkdir(exist_ok=True)
pd.DataFrame.to_csv(fracFloodArea, outputPath/'FFA_sylhet_allROI_allGauges_NASAIMPACT_v2.csv', index=True)

# %%
fracFloodArea
# Out:
# ROI        SW172.5_10km SW172.5_15km SW172.5_5km SW173_10km SW173_15km  \
# Date
# 2022-05-01     0.038951     0.037124    0.034695   0.038624   0.043566
# 2022-05-11     0.242176     0.216392     0.20854   0.121924   0.126908
# 2022-05-13     0.371452     0.359985    0.266779   0.354804    0.38697
# 2022-05-23     0.403075     0.455049    0.285776   0.562714   0.550717
# 2022-05-25     0.293789     0.372447    0.164784   0.490375   0.490636
# 2022-06-04     0.331226      0.38935     0.21543   0.432013   0.441997
# 2022-06-06     0.340894     0.410881     0.18925    0.48557   0.485429
# 2022-06-16     0.332215     0.404776    0.200298   0.469291   0.462029
# 2022-06-18     0.332693      0.38692     0.23444   0.570678   0.570435
# 2022-06-28     0.479496     0.520976    0.341777   0.606305   0.587145
# 2022-06-30     0.477285     0.516892    0.356739   0.614319   0.591176
# 2022-07-12     0.432832     0.475742    0.294733   0.540584   0.528925
# 2022-07-22     0.278185     0.356215    0.134832   0.460352   0.432714
# 2022-07-24     0.325349     0.377752    0.240231   0.399156   0.369305
# 2022-08-03     0.300794     0.365777    0.157969    0.32791   0.296854
# 2022-08-05     0.266037     0.321326    0.152201    0.31604   0.283582
# 2022-08-15     0.111886     0.164992    0.072739   0.207565    0.18909
# 2022-08-27     0.096836     0.119682    0.044486   0.181069   0.183935
# 2022-08-29     0.081542      0.10239    0.045986   0.164472   0.170398
#
# ROI        SW173_5km SW175.5_10km SW175.5_15km SW175.5_5km SW251_10km  \
# Date
# 2022-05-01  0.045891     0.043386     0.034026    0.051989   0.035424
# 2022-05-11  0.102014     0.068647     0.056731      0.0815   0.114727
# 2022-05-13  0.344837     0.202325     0.216355    0.158114   0.522125
# 2022-05-23  0.613673      0.56353     0.545173    0.527561    0.50442
# 2022-05-25  0.549239     0.536507     0.519359    0.485052   0.432928
# 2022-06-04   0.48678     0.535609     0.508296    0.523561   0.484093
# 2022-06-06  0.522978     0.535036     0.519286    0.504208   0.555267
# 2022-06-16  0.501208     0.515248     0.499641    0.476424   0.546185
# 2022-06-18  0.593128     0.614091     0.605308    0.596507   0.622522
# 2022-06-28  0.669711     0.619257     0.617369    0.591936   0.540579
# 2022-06-30  0.671106     0.579853     0.580022    0.533447   0.563821
# 2022-07-12  0.627824     0.513992     0.510487    0.436898   0.395894
# 2022-07-22  0.558734     0.494422     0.481224    0.433333   0.267507
# 2022-07-24  0.488487     0.477986     0.455654    0.411122   0.262394
# 2022-08-03  0.407554     0.434534     0.410062    0.371082   0.161942
# 2022-08-05  0.382779     0.490967     0.440322    0.445549   0.132924
# 2022-08-15  0.245194     0.406723     0.371917    0.364795   0.103198
# 2022-08-27  0.226069     0.370102     0.357903    0.289438    0.15424
# 2022-08-29  0.217338     0.333295     0.312908    0.266281   0.120845
#
# ROI        SW251_15km SW251_5km SW266_10km SW266_15km SW266_5km SW267_10km  \
# Date
# 2022-05-01   0.043219  0.024194   0.035547   0.033514  0.038202   0.018269
# 2022-05-11    0.12886  0.092338   0.073569   0.106735  0.034259   0.156286
# 2022-05-13   0.493761  0.495381   0.550531   0.444512  0.551676   0.267537
# 2022-05-23   0.523079  0.358228     0.6205   0.498506  0.639306   0.350806
# 2022-05-25   0.459394  0.240228   0.524518   0.432523   0.48641   0.293242
# 2022-06-04   0.488072  0.347453   0.515484   0.420444  0.488364   0.219766
# 2022-06-06   0.546713  0.460909   0.606165   0.481857  0.613075   0.306235
# 2022-06-16    0.53971  0.518927    0.62607   0.487566  0.620358   0.310693
# 2022-06-18   0.597883  0.605729   0.640256   0.514091  0.682154    0.40384
# 2022-06-28    0.54773  0.406078   0.639486   0.523802  0.669897   0.369042
# 2022-06-30    0.56216  0.469052   0.648376    0.52775  0.674526   0.361609
# 2022-07-12    0.43252  0.207697   0.566691   0.462719  0.595173   0.240916
# 2022-07-22   0.307059  0.096784   0.377677   0.326497  0.328133   0.188187
# 2022-07-24   0.287668  0.149653   0.347609    0.29621  0.315587   0.161729
# 2022-08-03   0.195106  0.064155   0.303854   0.253882  0.248047   0.131266
# 2022-08-05    0.16244  0.058152   0.267019   0.222509  0.206887   0.107882
# 2022-08-15   0.120929  0.052376    0.16923   0.133857  0.130189   0.074203
# 2022-08-27    0.16612  0.069967   0.192223   0.157048  0.157511   0.078297
# 2022-08-29   0.141019  0.057412   0.160043    0.12866  0.126691   0.065047
#
# ROI        SW267_15km SW267_5km Sylhet_District Sylhet_Upazilla
# Date
# 2022-05-01    0.01983  0.023176        0.045054        0.024372
# 2022-05-11   0.169964  0.098488        0.149999        0.108618
# 2022-05-13   0.343872  0.125133        0.454619        0.310883
# 2022-05-23    0.45238  0.156991        0.586484        0.445056
# 2022-05-25   0.396385  0.114436        0.530735        0.395344
# 2022-06-04   0.335205  0.074536        0.500632        0.335905
# 2022-06-06   0.426049  0.121359        0.554311        0.437263
# 2022-06-16   0.413196   0.09317         0.52428        0.466243
# 2022-06-18   0.508536  0.198687         0.62721        0.472738
# 2022-06-28   0.482739  0.159022        0.614441        0.438055
# 2022-06-30   0.475202  0.136267        0.612015        0.448302
# 2022-07-12   0.351506  0.100596        0.507947        0.326277
# 2022-07-22   0.292747  0.078523        0.420647        0.304487
# 2022-07-24   0.261903   0.06677        0.402726        0.267192
# 2022-08-03   0.204998  0.056571        0.327714         0.23715
# 2022-08-05   0.179806    0.0547        0.298666        0.187525
# 2022-08-15   0.124527  0.046595        0.216352        0.140519
# 2022-08-27   0.153202  0.042199        0.232561        0.174246
# 2022-08-29    0.11057  0.041909        0.203682        0.125189
