# %% [markdown]
# # Project: NIP
# # Subroject: Sylhet Floods, June 2022
# ## Script: run_modifiedDevries_S1.ipynb
# This script runs the modified Devires surface water mapping algorithm on Sentinel-1 data for the Sylet June 2022 flooding. The algorithm was modified and applied by Thomas et al. (2021).
#
# It uses elements created by Jonathan (building off Thomas et al. (2021)) for the time series fusion part of the NIP project, principally:

# %%
import ee

# %%
ee.Authenticate()
# Out:
# <p>To authorize access needed by Earth Engine, open the following
#         URL in a web browser and follow the instructions:</p>
#         <p><a href=https://code.earthengine.google.com/client-auth?scopes=https%3A//www.googleapis.com/auth/earthengine%20https%3A//www.googleapis.com/auth/devstorage.full_control&request_id=rTPXiqQwspigf0yjo3MaZDSJoHpakF8TwCABIvsC3hI&tc=rg0LZlFMG_XjPW5D9p_n8zGtOkyztaqqA-oo-rM-nNg&cc=NRUVxo_S1DfZACHmfYF9aqjZ9a99yo_Qr7oixHoap1Y>https://code.earthengine.google.com/client-auth?scopes=https%3A//www.googleapis.com/auth/earthengine%20https%3A//www.googleapis.com/auth/devstorage.full_control&request_id=rTPXiqQwspigf0yjo3MaZDSJoHpakF8TwCABIvsC3hI&tc=rg0LZlFMG_XjPW5D9p_n8zGtOkyztaqqA-oo-rM-nNg&cc=NRUVxo_S1DfZACHmfYF9aqjZ9a99yo_Qr7oixHoap1Y</a></p>
#         <p>The authorization workflow will generate a code, which you should paste in the box below.</p>
# Enter verification code:  4/1AfgeXvsSZP3V-Y89sXDlmpf9wFlNLiXEZK2ji60MJU3AqFqAd_F1_LXYOkM
# Successfully saved authorization token.

# %%
ee.Initialize()

# %%
from pathlib import Path
import os
import sys
import pandas as pd
import numpy as np
import geemap
from functools import partial
import multiprocessing

# %%
# Set the root path for working and saving outputs
rootPath = Path('C:/Users/alexsaunders/Documents/01_uoa/04_git/NIP/Sylhet/DataPreparation')
#list((DevriesPath).iterdir())

# %%
# Set the module path for accessing the Devries scripts
module_path = os.path.abspath(os.path.join('../../Fusion/Source'))
if module_path not in sys.path:
    sys.path.append(module_path)
import Devries.DevriesMethods as dv

# %% [markdown]
# ## PART 0: Load imports

# %%
# Load imports:
# (1) FeatureCollectios containing the administrative areas
upazilla = ee.FeatureCollection("projects/ee-nip/assets/ShapeFiles/Admin/Upazilas")
region = ee.FeatureCollection("projects/ee-nip/assets/ShapeFiles/Admin/Regions")
district = ee.FeatureCollection("projects/ee-nip/assets/ShapeFiles/Admin/Districts")
# (2) ImageCollections for the target satellites / sensors 
# Load Sentinel-1 imageCollection
sentinel1 = ee.ImageCollection("COPERNICUS/S1_GRD")

# %% [markdown]
# ## PART 1: Define the ROI

# %%
# Define ROIs for the different admin areas containing Sylhet
roi_upa = upazilla.filter(ee.Filter.eq('NAME_3', 'Sylhet Sadar'))
roi_dist = district.filter(ee.Filter.eq('NAME_2', 'Sylhet'))
roi_reg = region.filter(ee.Filter.eq('NAME_1', 'Sylhet'))

# %% [markdown]
# ## PART 2: Define the TOI

# %%
# Define the time period of interest
start_date = ee.Date('2022-05-01')
end_date = ee.Date('2022-09-01')

# %% [markdown]
# ## PART 3: Filter the Sentinel-1 collection for ROI and TOI

# %%
# Filter the Sentinel-1 collection for ROI and TOI - currently using the Sylhet District
S1Filtered = sentinel1.filterDate(ee.Date(start_date), ee.Date(end_date)).filter(ee.Filter.bounds(roi_dist))

# Check how many images returned, and get the dates and orbit numbers
if S1Filtered == None: 
    print('No images for the collection for the TOI and ROI')
else:
    dates = S1Filtered.aggregate_array("system:time_start").getInfo()
    orbitNumber_start = S1Filtered.aggregate_array("orbitNumber_start").getInfo()
    print(S1Filtered.size().getInfo(),'images for the TOI and ROI')
    print('Image dates: ', pd.to_datetime(dates, unit='ms'))
    print('orbitNumbers: ', orbitNumber_start)
# Out:
# 19 images for the TOI and ROI
# Image dates:  DatetimeIndex(['2022-05-01 23:47:40', '2022-05-11 11:56:42',
#                '2022-05-13 23:47:40', '2022-05-23 11:56:43',
#                '2022-05-25 23:47:41', '2022-06-04 11:56:44',
#                '2022-06-06 23:47:42', '2022-06-16 11:56:45',
#                '2022-06-18 23:47:43', '2022-06-28 11:56:46',
#                '2022-06-30 23:47:44', '2022-07-12 23:47:44',
#                '2022-07-22 11:56:47', '2022-07-24 23:47:45',
#                '2022-08-03 11:56:48', '2022-08-05 23:47:46',
#                '2022-08-15 11:56:49', '2022-08-27 11:56:49',
#                '2022-08-29 23:47:47'],
#               dtype='datetime64[ns]', freq=None)
# orbitNumbers:  [43024, 43163, 43199, 43338, 43374, 43513, 43549, 43688, 43724, 43863, 43899, 44074, 44213, 44249, 44388, 44424, 44563, 44738, 44774]

# %%
# Get the projection and scale information
proj = S1Filtered.first().select(1).projection().getInfo()
scale = S1Filtered.first().select(1).projection().nominalScale().getInfo()

# %% [markdown]
# ## PART 4: Chipping
# It is necessary to create a grid to chip up the data for the S1 algorithm since geemap export has a maximum file size of around 50 MB

# %%
# Create a grid at the appropriate scale and number of pixels (scale = chipsize * resolution)
# Create function to create the grid
def create_grid(roi):
    grid = roi.geometry().coveringGrid(proj=roi.geometry().projection(), scale=1024*scale)
    return grid

# %%
# Use the bounding box of the ROI for the grid boundary (can instead use the ROI itself)
roi_bounds = ee.FeatureCollection(roi_dist.first().geometry().bounds())

# %%
# Apply the create grid function to create grid as Feature Collection
grid = create_grid(roi_bounds) #roi
grid_size = grid.size().getInfo() # number of chips
grid_list = grid.toList(grid_size)

# %%
# Show the grid using geemap
gridCenter = roi_bounds.first().geometry().centroid(1).getInfo()['coordinates']
Map = geemap.Map(center=(gridCenter[1], gridCenter[0]), zoom=9)
Map.addLayer(grid)
Map.addLayer(roi_dist)

Map
# Out:
# Map(center=[24.89262612858011, 92.07147040621301], controls=(WidgetControl(options=['position', 'transparent_b…

# %% [markdown]
# ## PART 5: Apply the Thomas et al. (2021) modified DeVries surface water algorithm
# Run the surface water mapping for all S1 images over the Sylhet flooding and export output geotiffs.

# %%
# Import modules from the Devries folder
import importlib

import Devries.ExportChipsHelper as ExportHelper
importlib.reload(ExportHelper)

import Devries.DevriesMethods as dv
importlib.reload(dv)

import Devries.DevriesFloodMap as dvFM
importlib.reload(dvFM)

import Devries.DevriesSingleOrbitFloodMap as dvSOFM
importlib.reload(dvSOFM)
# Out:
# <module 'Devries.DevriesSingleOrbitFloodMap' from 'C:\\Users\\alexsaunders\\Documents\\01_uoa\\04_git\\NIP\\Fusion\\Source\\Devries\\DevriesSingleOrbitFloodMap.py'>

# %%
# Define the start and end dates for the dry baseline
# VALUES USED IN FIRST VERSION
# baseStart = '2018-10-28'  
# baseEnd = '2018-12-11'

baseStart = '2019-01-10' 
baseEnd = '2019-02-26'

# Provide name for the ROI for naming the exported files
roi_name = 'sylhet_dist'

# Create the output folder for saving the exported files
rootPath = Path('Z:/media/mule/Projects/NASA/NIP/Data/Raster/Sylhet/')
outputPath = rootPath/'Sen1MitchellSingleOrbit/dryBaseV2'
outputPath.mkdir(exist_ok=True)

# %%
# Loop over each orbit number and chip and apply the surface water mapping algorithm
for i in range(0, len(orbitNumber_start)):
    orbitNumber = orbitNumber_start[i]
    imageDate = dates[i]
    print('Orbit: ', orbitNumber, '. Date: ', pd.to_datetime(imageDate, unit='ms').strftime("%Y%m%d"))
    
    for j in range(0, grid_size):
       
        chip_id = range(grid_size)[j]
        chip = ee.Feature(grid_list.get(chip_id)).geometry()
        
        # Check if tif has already been created before, if so skip
        flood_map_image_path = roi_name + '_' + '{:0>2}'.format(chip_id) + '_' + str(pd.to_datetime(imageDate, unit='ms').strftime("%Y%m%d")) + '_' + str(orbitNumber) + '.tif'
        if os.path.exists(outputPath/flood_map_image_path):
            #print('Already exists')
            continue
        
        print('Chip: ', chip_id)
        
        # Run the flood map image function for the given orbitNumber, date and chip
        flood_map_image = dvSOFM.getGTImageSingleOrbit(chip, baseStart, baseEnd, orbitNumber, imageDate)

        # Export the output flood map image
        #geemap.download_ee_image(flood_map_image, outputPath/flood_map_image_path, scale=scale, crs=proj['crs'])# ERROR "partially initialized module 'rasterio' has no attribute '_loading' (most likely due to a circular import)"
        geemap.ee_export_image(flood_map_image, outputPath/flood_map_image_path, scale=scale, crs=proj['crs'], region=chip, file_per_band=False)
# Out:
# Orbit:  43024 . Date:  20220501
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Orbit:  43163 . Date:  20220511
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Orbit:  43199 . Date:  20220513
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Orbit:  43338 . Date:  20220523
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Orbit:  43374 . Date:  20220525
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Orbit:  43513 . Date:  20220604
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Orbit:  43549 . Date:  20220606
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Orbit:  43688 . Date:  20220616
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Orbit:  43724 . Date:  20220618
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Orbit:  43863 . Date:  20220628
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Orbit:  43899 . Date:  20220630
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Orbit:  44074 . Date:  20220712
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Already exists
# Chip:  59
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/a9f759cb54843a0b789fa58d13f4fc02-bf7850032e216bd1ad18683c2edbb448:getPixels
# Please wait ...
# Data downloaded to Z:\media\mule\Projects\NASA\NIP\Data\Raster\Sylhet\Sen1MitchellSingleOrbit\dryBaseV2\sylhet_dist_59_20220712_44074.tif
# Chip:  60
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/591371872e559ecaebc340df3226a44d-b41b8928ee505d2e00349b5386dcf6e6:getPixels
# Please wait ...
# Data downloaded to Z:\media\mule\Projects\NASA\NIP\Data\Raster\Sylhet\Sen1MitchellSingleOrbit\dryBaseV2\sylhet_dist_60_20220712_44074.tif
# Chip:  61
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/b2fa0f57130596c923ca97efed03280c-92300430c6bb5ea4b512b76279c82fa4:getPixels
# Please wait ...
# Data downloaded to Z:\media\mule\Projects\NASA\NIP\Data\Raster\Sylhet\Sen1MitchellSingleOrbit\dryBaseV2\sylhet_dist_61_20220712_44074.tif
# Chip:  62
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/7595a2a75e733e2630425ddcf3d2e9fc-4b14796c7f230f263384211893c10b05:getPixels
# Please wait ...
# Data downloaded to Z:\media\mule\Projects\NASA\NIP\Data\Raster\Sylhet\Sen1MitchellSingleOrbit\dryBaseV2\sylhet_dist_62_20220712_44074.tif
# Chip:  63
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/c76610be495fd40a527bbd43d5ff1503-e785c98e9b2e4821f3828035cabd6413:getPixels
# Please wait ...
# Data downloaded to Z:\media\mule\Projects\NASA\NIP\Data\Raster\Sylhet\Sen1MitchellSingleOrbit\dryBaseV2\sylhet_dist_63_20220712_44074.tif
# Chip:  64
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/2df33dbfba43902e23b95c8057569bcd-6f7a033227ab13f5c85099c1fc7f1980:getPixels
# Please wait ...
# Data downloaded to Z:\media\mule\Projects\NASA\NIP\Data\Raster\Sylhet\Sen1MitchellSingleOrbit\dryBaseV2\sylhet_dist_64_20220712_44074.tif
# Chip:  65
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/2c70581ffb01da8290d553ed5711a9ce-7b3e503b46ac20023d541c4d14094114:getPixels
# Please wait ...
# Data downloaded to Z:\media\mule\Projects\NASA\NIP\Data\Raster\Sylhet\Sen1MitchellSingleOrbit\dryBaseV2\sylhet_dist_65_20220712_44074.tif
# Chip:  66
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/5b747a79a61ede7049de37fa19966e6f-6f0568d6575bd8d4e57160057c972bae:getPixels
# Please wait ...
# Data downloaded to Z:\media\mule\Projects\NASA\NIP\Data\Raster\Sylhet\Sen1MitchellSingleOrbit\dryBaseV2\sylhet_dist_66_20220712_44074.tif
# Chip:  67
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/9093b02383638ecddb4719c44a08f32d-4b98574434c2b0a6f54740b0a7a1de04:getPixels
# Please wait ...
# Data downloaded to Z:\media\mule\Projects\NASA\NIP\Data\Raster\Sylhet\Sen1MitchellSingleOrbit\dryBaseV2\sylhet_dist_67_20220712_44074.tif
# Chip:  68
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/903464692ebb49bb98272fd9e1936fbf-9db3da15cd7b7f5e2f0b12288de5e537:getPixels
# Please wait ...
# Data downloaded to Z:\media\mule\Projects\NASA\NIP\Data\Raster\Sylhet\Sen1MitchellSingleOrbit\dryBaseV2\sylhet_dist_68_20220712_44074.tif
# Chip:  69
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/d758a059e8405854d97311353f4bc61e-f42dda4ca922cdce28ec638c7b1e6649:getPixels
# Please wait ...
# Data downloaded to Z:\media\mule\Projects\NASA\NIP\Data\Raster\Sylhet\Sen1MitchellSingleOrbit\dryBaseV2\sylhet_dist_69_20220712_44074.tif
# Orbit:  44213 . Date:  20220722
# Chip:  0
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/1839e0d39d56dccc6b1ee4187e4236fe-cfd6e8e0ada72b42cfeaad6962e856d0:getPixels
# Please wait ...
# Data downloaded to Z:\media\mule\Projects\NASA\NIP\Data\Raster\Sylhet\Sen1MitchellSingleOrbit\dryBaseV2\sylhet_dist_00_20220722_44213.tif
# Chip:  1
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/49e1180580423864fabca26f91f5aed2-9e8280e75246ae5db0992227f89e415a:getPixels
# Please wait ...
# Data downloaded to Z:\media\mule\Projects\NASA\NIP\Data\Raster\Sylhet\Sen1MitchellSingleOrbit\dryBaseV2\sylhet_dist_01_20220722_44213.tif
# Chip:  2
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/498f04bc0a85cb23bfa7c1b92923029f-50e576ee657ae81abd36a562f3902e10:getPixels
# Please wait ...
# Data downloaded to Z:\media\mule\Projects\NASA\NIP\Data\Raster\Sylhet\Sen1MitchellSingleOrbit\dryBaseV2\sylhet_dist_02_20220722_44213.tif
# Chip:  3
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/16ba8f5733c82869f658a3add75a3291-375c09ba39838b7097e5dc2c5626c5b4:getPixels
# Please wait ...
# Data downloaded to Z:\media\mule\Projects\NASA\NIP\Data\Raster\Sylhet\Sen1MitchellSingleOrbit\dryBaseV2\sylhet_dist_03_20220722_44213.tif
# Chip:  4
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/336c6b39239f3c1f70adc26655bf7154-71adcc6cabd0074cc8181638bf3ab2f5:getPixels
# Please wait ...
# Data downloaded to Z:\media\mule\Projects\NASA\NIP\Data\Raster\Sylhet\Sen1MitchellSingleOrbit\dryBaseV2\sylhet_dist_04_20220722_44213.tif
# Chip:  5
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/d17f49c90cf7e59c1e51a41aa05d47d4-dad1621008db1e561fedc7fd7f9a087f:getPixels
# Please wait ...
# Data downloaded to Z:\media\mule\Projects\NASA\NIP\Data\Raster\Sylhet\Sen1MitchellSingleOrbit\dryBaseV2\sylhet_dist_05_20220722_44213.tif
# Chip:  6
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/1d15c6fb11f8a056f0a2b817f8873265-72c8c27bfe71c823757e8c144382b279:getPixels
# Please wait ...
# Data downloaded to Z:\media\mule\Projects\NASA\NIP\Data\Raster\Sylhet\Sen1MitchellSingleOrbit\dryBaseV2\sylhet_dist_06_20220722_44213.tif
# Chip:  7
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/500ada836eb8bd14658f4ea098e14e86-3766cb33857482cac3566b33ec438b5d:getPixels
# Please wait ...
# Data downloaded to Z:\media\mule\Projects\NASA\NIP\Data\Raster\Sylhet\Sen1MitchellSingleOrbit\dryBaseV2\sylhet_dist_07_20220722_44213.tif
# Chip:  8
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/15613d737c1f85f19adfa08960086fe7-942bb16eae8f05327cfc1f951b0607ab:getPixels
# Please wait ...
# Data downloaded to Z:\media\mule\Projects\NASA\NIP\Data\Raster\Sylhet\Sen1MitchellSingleOrbit\dryBaseV2\sylhet_dist_08_20220722_44213.tif
# Chip:  9
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/7cb9def51111ff5ade43c5c4db4e5ba7-7c1cc1086a0ac2af703cf70d05443a2e:getPixels
# Please wait ...
# Data downloaded to Z:\media\mule\Projects\NASA\NIP\Data\Raster\Sylhet\Sen1MitchellSingleOrbit\dryBaseV2\sylhet_dist_09_20220722_44213.tif
# Chip:  10
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/f5b75c392c5417a5a9177efdd966d5ce-d0d2bf57b8724b93f84c0668cd835d6a:getPixels
# Please wait ...
# Data downloaded to Z:\media\mule\Projects\NASA\NIP\Data\Raster\Sylhet\Sen1MitchellSingleOrbit\dryBaseV2\sylhet_dist_10_20220722_44213.tif
# Chip:  11
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/e98721279cdcc2ec5b546f85a01d0389-3c2dc77c52b148b6401c5eaa9d19dd18:getPixels
# Please wait ...
# Data downloaded to Z:\media\mule\Projects\NASA\NIP\Data\Raster\Sylhet\Sen1MitchellSingleOrbit\dryBaseV2\sylhet_dist_11_20220722_44213.tif
# Chip:  12
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/9dae3712cd3d061ead239d1e56a8b2ca-fbe69cacc0b8474a17ae78d5775bc7eb:getPixels
# Please wait ...
# Data downloaded to Z:\media\mule\Projects\NASA\NIP\Data\Raster\Sylhet\Sen1MitchellSingleOrbit\dryBaseV2\sylhet_dist_12_20220722_44213.tif
# Chip:  13
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/c79a4123ce2840c50dc0f1d3a2581c36-65f1066b036634feb5fa3115c468e6bf:getPixels
# Please wait ...
# Data downloaded to Z:\media\mule\Projects\NASA\NIP\Data\Raster\Sylhet\Sen1MitchellSingleOrbit\dryBaseV2\sylhet_dist_13_20220722_44213.tif
# Chip:  14
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/b6144ede17dcf200109df58a72b146b0-129a627a4077a09df4c848ecd66541a9:getPixels
# Please wait ...
# Data downloaded to Z:\media\mule\Projects\NASA\NIP\Data\Raster\Sylhet\Sen1MitchellSingleOrbit\dryBaseV2\sylhet_dist_14_20220722_44213.tif
# Chip:  15
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/8c6fa9ad10f453ba496825e2f333c20a-5f7ff0a55e8ca503b4a9d136bb446f9a:getPixels
# Please wait ...
# Data downloaded to Z:\media\mule\Projects\NASA\NIP\Data\Raster\Sylhet\Sen1MitchellSingleOrbit\dryBaseV2\sylhet_dist_15_20220722_44213.tif
# Chip:  16
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/001393812f7a7378544380618be6482c-e152669766c6271f9ef0b976f8420648:getPixels
# Please wait ...
# Data downloaded to Z:\media\mule\Projects\NASA\NIP\Data\Raster\Sylhet\Sen1MitchellSingleOrbit\dryBaseV2\sylhet_dist_16_20220722_44213.tif
# Chip:  17
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/13d921f4079cc872e81c5e13f3ae2bb4-ea3902b833d497159b80af97561759d7:getPixels
# Please wait ...
# Data downloaded to Z:\media\mule\Projects\NASA\NIP\Data\Raster\Sylhet\Sen1MitchellSingleOrbit\dryBaseV2\sylhet_dist_17_20220722_44213.tif
# Chip:  18
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/cd2ca11c3d40a3b4856d2804af40b957-488e14b51324466945ced46b41db8ea0:getPixels
# Please wait ...
# Data downloaded to Z:\media\mule\Projects\NASA\NIP\Data\Raster\Sylhet\Sen1MitchellSingleOrbit\dryBaseV2\sylhet_dist_18_20220722_44213.tif
# Chip:  19
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/68c09e7d60e89a5450c6b43e5b09ebe6-948cbe7499d82d5726417bfb8d3f227c:getPixels
# Please wait ...
# Data downloaded to Z:\media\mule\Projects\NASA\NIP\Data\Raster\Sylhet\Sen1MitchellSingleOrbit\dryBaseV2\sylhet_dist_19_20220722_44213.tif
# Chip:  20
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/a7d4755a79ac2bbfbffafeee212a505b-deec06b0ec5e3fc7b7b8e4b87b5810a6:getPixels
# Please wait ...
# Data downloaded to Z:\media\mule\Projects\NASA\NIP\Data\Raster\Sylhet\Sen1MitchellSingleOrbit\dryBaseV2\sylhet_dist_20_20220722_44213.tif
# Chip:  21
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/3826463fa0656229b25c740bb9781b44-b25e619dc3113418466eb671119e0a2e:getPixels
# Please wait ...
# Data downloaded to Z:\media\mule\Projects\NASA\NIP\Data\Raster\Sylhet\Sen1MitchellSingleOrbit\dryBaseV2\sylhet_dist_21_20220722_44213.tif
# Chip:  22
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/bf2764f6e842266090df19a6033efd01-fd22d77906d195622495a6cacd414949:getPixels
# Please wait ...
# Data downloaded to Z:\media\mule\Projects\NASA\NIP\Data\Raster\Sylhet\Sen1MitchellSingleOrbit\dryBaseV2\sylhet_dist_22_20220722_44213.tif
# Chip:  23
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/dba3c69f4158480cf664b665337a9732-864edad541b0d7044ad4c2dd92070c0d:getPixels
# Please wait ...
# Data downloaded to Z:\media\mule\Projects\NASA\NIP\Data\Raster\Sylhet\Sen1MitchellSingleOrbit\dryBaseV2\sylhet_dist_23_20220722_44213.tif
# Chip:  24
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/710c66bfb38f3aee15221bc14a6f7855-c76ef33a51d00d3f21d7908ec501c53f:getPixels
# Please wait ...
# Data downloaded to Z:\media\mule\Projects\NASA\NIP\Data\Raster\Sylhet\Sen1MitchellSingleOrbit\dryBaseV2\sylhet_dist_24_20220722_44213.tif
# Chip:  25
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/d29e0814286f7ad15dfed95778e30b18-5aeeeffb761edb846d7a98eb7ed50de7:getPixels
# Please wait ...
# Data downloaded to Z:\media\mule\Projects\NASA\NIP\Data\Raster\Sylhet\Sen1MitchellSingleOrbit\dryBaseV2\sylhet_dist_25_20220722_44213.tif
# Chip:  26
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/00490a5d08f4a8086e49bca3685e43ce-2a1d95eae17d3893c0fc86138a23e558:getPixels
# Please wait ...
# Data downloaded to Z:\media\mule\Projects\NASA\NIP\Data\Raster\Sylhet\Sen1MitchellSingleOrbit\dryBaseV2\sylhet_dist_26_20220722_44213.tif
# Chip:  27
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/45568d114911bf7ac85b23340cc19e76-9b8b97ddf1ece30ba69c177f7e8bb31e:getPixels
# Please wait ...
# Data downloaded to Z:\media\mule\Projects\NASA\NIP\Data\Raster\Sylhet\Sen1MitchellSingleOrbit\dryBaseV2\sylhet_dist_27_20220722_44213.tif
# Chip:  28
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/b3e693a5f375fe29b694afd0767f1c8d-e0ecdc187e8be690511d4f983cd17259:getPixels
# Please wait ...
# Data downloaded to Z:\media\mule\Projects\NASA\NIP\Data\Raster\Sylhet\Sen1MitchellSingleOrbit\dryBaseV2\sylhet_dist_28_20220722_44213.tif
# Chip:  29
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/6eceeba17de5a370e86cc4800a4194b3-65eac72b3f7aa260068f5f08bfa85a31:getPixels
# Please wait ...
# Data downloaded to Z:\media\mule\Projects\NASA\NIP\Data\Raster\Sylhet\Sen1MitchellSingleOrbit\dryBaseV2\sylhet_dist_29_20220722_44213.tif
# Chip:  30
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/23a23e2f4e6c7a3d20088fef4b51a063-e7ea79710d23d3123594aabbfadb54dd:getPixels
# Please wait ...
# Data downloaded to Z:\media\mule\Projects\NASA\NIP\Data\Raster\Sylhet\Sen1MitchellSingleOrbit\dryBaseV2\sylhet_dist_30_20220722_44213.tif
# Chip:  31
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/f873b25a88bbe1273d39cd795aedcca6-d94b56508a438ecd6e2aa18c3d6d6459:getPixels
# Please wait ...
# Data downloaded to Z:\media\mule\Projects\NASA\NIP\Data\Raster\Sylhet\Sen1MitchellSingleOrbit\dryBaseV2\sylhet_dist_31_20220722_44213.tif
# Chip:  32
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/ddd5a9e6168789ad02ef21a23b9eee27-9306dfae04f7f51784fab6aeb5f2d04b:getPixels
# Please wait ...
# Data downloaded to Z:\media\mule\Projects\NASA\NIP\Data\Raster\Sylhet\Sen1MitchellSingleOrbit\dryBaseV2\sylhet_dist_32_20220722_44213.tif
# Chip:  33
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/bc3e249d2812b1ffcaa426db10e62d5c-b3597cd7abf044f745cd9ef970e8d57c:getPixels
# Please wait ...
# Data downloaded to Z:\media\mule\Projects\NASA\NIP\Data\Raster\Sylhet\Sen1MitchellSingleOrbit\dryBaseV2\sylhet_dist_33_20220722_44213.tif
# Chip:  34
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/6fe66e296d24e82d8a9043f83c0dbc31-c4374c1af38d0df3c64e96a5b78f06fe:getPixels
# Please wait ...
# Data downloaded to Z:\media\mule\Projects\NASA\NIP\Data\Raster\Sylhet\Sen1MitchellSingleOrbit\dryBaseV2\sylhet_dist_34_20220722_44213.tif
# Chip:  35
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/9d86212b33af05d38dfa1ee983d9049e-0f1e171053616eec6017ad6032215853:getPixels
# Please wait ...
# Data downloaded to Z:\media\mule\Projects\NASA\NIP\Data\Raster\Sylhet\Sen1MitchellSingleOrbit\dryBaseV2\sylhet_dist_35_20220722_44213.tif
# Chip:  36
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/45c330e125908f99eaf8d8903f1fc17f-40506ff0eaf7ea61babc60ad09e93c09:getPixels
# Please wait ...
# Data downloaded to Z:\media\mule\Projects\NASA\NIP\Data\Raster\Sylhet\Sen1MitchellSingleOrbit\dryBaseV2\sylhet_dist_36_20220722_44213.tif
# Chip:  37
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/0d89307e3ea9c8e5404c6367cdc9d156-2a4ff8afd3d8e41758ea9e255f500958:getPixels
# Please wait ...
# Data downloaded to Z:\media\mule\Projects\NASA\NIP\Data\Raster\Sylhet\Sen1MitchellSingleOrbit\dryBaseV2\sylhet_dist_37_20220722_44213.tif
# Chip:  38
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/b09336960e89992547eb36e8eca5c4e3-d7842e7997bbe2ff45a7d4ce5baaff71:getPixels
# Please wait ...
# Data downloaded to Z:\media\mule\Projects\NASA\NIP\Data\Raster\Sylhet\Sen1MitchellSingleOrbit\dryBaseV2\sylhet_dist_38_20220722_44213.tif
# Chip:  39
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/47698f4198949211c2abf6ae788cca6c-f15372015ca1fe680f37f745e6db8d16:getPixels
# Please wait ...
# Data downloaded to Z:\media\mule\Projects\NASA\NIP\Data\Raster\Sylhet\Sen1MitchellSingleOrbit\dryBaseV2\sylhet_dist_39_20220722_44213.tif
# Chip:  40
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/3bf7c476e1b1f45a9720e7ff119955b8-1580aac1b10441e2af9e2a45d7907c90:getPixels
# Please wait ...
# Data downloaded to Z:\media\mule\Projects\NASA\NIP\Data\Raster\Sylhet\Sen1MitchellSingleOrbit\dryBaseV2\sylhet_dist_40_20220722_44213.tif
# Chip:  41
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/5b9ab95d7adf9be8027e6ce5e1acd7fa-663870ad2473ba12723132716e079225:getPixels
# Please wait ...
# Data downloaded to Z:\media\mule\Projects\NASA\NIP\Data\Raster\Sylhet\Sen1MitchellSingleOrbit\dryBaseV2\sylhet_dist_41_20220722_44213.tif
# Chip:  42
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/6635c57fdef9142c08dba8c14283be78-6f55c1b6973353a9a51051c83191aa38:getPixels
# Please wait ...
# Data downloaded to Z:\media\mule\Projects\NASA\NIP\Data\Raster\Sylhet\Sen1MitchellSingleOrbit\dryBaseV2\sylhet_dist_42_20220722_44213.tif
# Chip:  43
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/e549134f4b862f87d7a379783c90e113-39628155fe348b1b4258c38df85eb53b:getPixels
# Please wait ...
# Data downloaded to Z:\media\mule\Projects\NASA\NIP\Data\Raster\Sylhet\Sen1MitchellSingleOrbit\dryBaseV2\sylhet_dist_43_20220722_44213.tif
# Chip:  44
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/708ce6df65e3eb6f4bbe333526e13e46-c03d7bfb2119e78247cab52199261185:getPixels
# Please wait ...
# Data downloaded to Z:\media\mule\Projects\NASA\NIP\Data\Raster\Sylhet\Sen1MitchellSingleOrbit\dryBaseV2\sylhet_dist_44_20220722_44213.tif
# Chip:  45
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/5c9265e57a6844ce1b109aaeaaf4b8d4-79d86769a01f905e5d8af0d45dc24042:getPixels
# Please wait ...
# Data downloaded to Z:\media\mule\Projects\NASA\NIP\Data\Raster\Sylhet\Sen1MitchellSingleOrbit\dryBaseV2\sylhet_dist_45_20220722_44213.tif
# Chip:  46
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/bc0f66f66f8c7c9a68de5e2fd4c01044-3b326aa620cbd329e7d90fd7724ac980:getPixels
# Please wait ...
# Data downloaded to Z:\media\mule\Projects\NASA\NIP\Data\Raster\Sylhet\Sen1MitchellSingleOrbit\dryBaseV2\sylhet_dist_46_20220722_44213.tif
# Chip:  47
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/d71ac6dbb7af6927640233e7bc728208-c51675da6d0a2e2babcc9723183c8537:getPixels
# Please wait ...
# Data downloaded to Z:\media\mule\Projects\NASA\NIP\Data\Raster\Sylhet\Sen1MitchellSingleOrbit\dryBaseV2\sylhet_dist_47_20220722_44213.tif
# Chip:  48
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/8a0bed89fcef33112e46d761c72afaf7-b15e71d45ffce6495ec91c0b72703ae3:getPixels
# Please wait ...
# Data downloaded to Z:\media\mule\Projects\NASA\NIP\Data\Raster\Sylhet\Sen1MitchellSingleOrbit\dryBaseV2\sylhet_dist_48_20220722_44213.tif
# Chip:  49
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/fffee4e7ddb0338e85b75b2712a6b196-a64609e3f74a06b84d43ee02994b7fa2:getPixels
# Please wait ...
# Data downloaded to Z:\media\mule\Projects\NASA\NIP\Data\Raster\Sylhet\Sen1MitchellSingleOrbit\dryBaseV2\sylhet_dist_49_20220722_44213.tif
# Chip:  50
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/5367c397c5fc64f15534022c61f24723-d053269b212075d095a6b99551d20697:getPixels
# Please wait ...
# Data downloaded to Z:\media\mule\Projects\NASA\NIP\Data\Raster\Sylhet\Sen1MitchellSingleOrbit\dryBaseV2\sylhet_dist_50_20220722_44213.tif
# Chip:  51
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/ac803e9121edc5d8b14cf6ce62a1df72-c88af0a10852775262703679d204b088:getPixels
# Please wait ...
# Data downloaded to Z:\media\mule\Projects\NASA\NIP\Data\Raster\Sylhet\Sen1MitchellSingleOrbit\dryBaseV2\sylhet_dist_51_20220722_44213.tif
# Chip:  52
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/f8a40d88e8e93d5ca7bbfae89837faa7-0edee21656bd7c1d8a91dda498916f75:getPixels
# Please wait ...
# Data downloaded to Z:\media\mule\Projects\NASA\NIP\Data\Raster\Sylhet\Sen1MitchellSingleOrbit\dryBaseV2\sylhet_dist_52_20220722_44213.tif
# Chip:  53
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/10b88e8e3cea3df69d4809ab37043fd4-f030ebee2fdc7ef067b2f77b933b9c97:getPixels
# Please wait ...
# Data downloaded to Z:\media\mule\Projects\NASA\NIP\Data\Raster\Sylhet\Sen1MitchellSingleOrbit\dryBaseV2\sylhet_dist_53_20220722_44213.tif
# Chip:  54
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/0136213dc0255966be5c4b3aedea96eb-1e5a6597acb581af34afd18495cb978d:getPixels
# Please wait ...
# Data downloaded to Z:\media\mule\Projects\NASA\NIP\Data\Raster\Sylhet\Sen1MitchellSingleOrbit\dryBaseV2\sylhet_dist_54_20220722_44213.tif
# Chip:  55
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/904955aed981224e8decd1c800491c65-01d6e0ece0b309bf039cfce9fb8cf9aa:getPixels
# Please wait ...
# Data downloaded to Z:\media\mule\Projects\NASA\NIP\Data\Raster\Sylhet\Sen1MitchellSingleOrbit\dryBaseV2\sylhet_dist_55_20220722_44213.tif
# Chip:  56
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/eaf66b5d876f73a1dd0d0601b8f69d70-14708d73c07723681db7cbc179a40393:getPixels
# Please wait ...
# Data downloaded to Z:\media\mule\Projects\NASA\NIP\Data\Raster\Sylhet\Sen1MitchellSingleOrbit\dryBaseV2\sylhet_dist_56_20220722_44213.tif
# Chip:  57
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/89a1a840b5a8268989670f4cc52583d6-df53ecb2d217529911e041eec5a2977a:getPixels
# Please wait ...
# Data downloaded to Z:\media\mule\Projects\NASA\NIP\Data\Raster\Sylhet\Sen1MitchellSingleOrbit\dryBaseV2\sylhet_dist_57_20220722_44213.tif
# Chip:  58
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/7248f61f07e273a043d109d58c6c2eb8-733e40617232bdd810d2ac0c4d290cfb:getPixels
# Please wait ...
# Data downloaded to Z:\media\mule\Projects\NASA\NIP\Data\Raster\Sylhet\Sen1MitchellSingleOrbit\dryBaseV2\sylhet_dist_58_20220722_44213.tif
# Chip:  59
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/464f2d9de49858acddf8cc4a50fa507c-d2119488ff596c4e2b6a48ca3a7843f6:getPixels
# Please wait ...
# Data downloaded to Z:\media\mule\Projects\NASA\NIP\Data\Raster\Sylhet\Sen1MitchellSingleOrbit\dryBaseV2\sylhet_dist_59_20220722_44213.tif
# Chip:  60
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/dcf20668d4219614025ef5fbe2cd1dea-e04fe966942a58536525116552a76110:getPixels
# Please wait ...
# Data downloaded to Z:\media\mule\Projects\NASA\NIP\Data\Raster\Sylhet\Sen1MitchellSingleOrbit\dryBaseV2\sylhet_dist_60_20220722_44213.tif
# Chip:  61
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/a4f7a1454d555fcbbf8eea5790066022-554d8f425e818045e9ae40fbc2e3bc4d:getPixels
# Please wait ...
# Data downloaded to Z:\media\mule\Projects\NASA\NIP\Data\Raster\Sylhet\Sen1MitchellSingleOrbit\dryBaseV2\sylhet_dist_61_20220722_44213.tif
# Chip:  62
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/cefaac7f4c8bd98f85ee0b4ea50aae34-32be2c51296f37a555f0e54533cb8449:getPixels
# Please wait ...
# Data downloaded to Z:\media\mule\Projects\NASA\NIP\Data\Raster\Sylhet\Sen1MitchellSingleOrbit\dryBaseV2\sylhet_dist_62_20220722_44213.tif
# Chip:  63
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/b55eebf91b58020f495e59b33aba1e47-d406847d3032c9e602d00a9fa4e537ae:getPixels
# Please wait ...
# Data downloaded to Z:\media\mule\Projects\NASA\NIP\Data\Raster\Sylhet\Sen1MitchellSingleOrbit\dryBaseV2\sylhet_dist_63_20220722_44213.tif
# Chip:  64
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/8e513ddb978cf53cdff53099cde6d0d7-3d5597601b979c78213e51093362bb30:getPixels
# Please wait ...
# Data downloaded to Z:\media\mule\Projects\NASA\NIP\Data\Raster\Sylhet\Sen1MitchellSingleOrbit\dryBaseV2\sylhet_dist_64_20220722_44213.tif
# Chip:  65
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/2865bc19dbdd843c252130175936dfbb-e2f7192909314cf370b6fdf80078afa9:getPixels
# Please wait ...
# Data downloaded to Z:\media\mule\Projects\NASA\NIP\Data\Raster\Sylhet\Sen1MitchellSingleOrbit\dryBaseV2\sylhet_dist_65_20220722_44213.tif
# Chip:  66
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/5e5132ff3b8e9dd4799b945b68f68758-0d617cb3ec681fd279dc392236c42f0a:getPixels
# Please wait ...
# Data downloaded to Z:\media\mule\Projects\NASA\NIP\Data\Raster\Sylhet\Sen1MitchellSingleOrbit\dryBaseV2\sylhet_dist_66_20220722_44213.tif
# Chip:  67
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/c9c486f39b6e5f4d05d315424d626592-5f8744da21f4a99b73ad9ac01c1f6b00:getPixels
# Please wait ...
# Data downloaded to Z:\media\mule\Projects\NASA\NIP\Data\Raster\Sylhet\Sen1MitchellSingleOrbit\dryBaseV2\sylhet_dist_67_20220722_44213.tif
# Chip:  68
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/81130afd19c817260005137c35fb9cd8-ea7042db88770acda5dd519f0f9ce056:getPixels
# Please wait ...
# Data downloaded to Z:\media\mule\Projects\NASA\NIP\Data\Raster\Sylhet\Sen1MitchellSingleOrbit\dryBaseV2\sylhet_dist_68_20220722_44213.tif
# Chip:  69
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/89e9568200c477ab3f0cc42e94107207-25b13e039299bad51226240bfb3fabfc:getPixels
# Please wait ...
# Data downloaded to Z:\media\mule\Projects\NASA\NIP\Data\Raster\Sylhet\Sen1MitchellSingleOrbit\dryBaseV2\sylhet_dist_69_20220722_44213.tif
# Orbit:  44249 . Date:  20220724
# Chip:  0
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/6ef05c2a00a0aeb915784097eb7a275d-e7566e6199475cc32ce42a1c5e854608:getPixels
# Please wait ...
# Data downloaded to Z:\media\mule\Projects\NASA\NIP\Data\Raster\Sylhet\Sen1MitchellSingleOrbit\dryBaseV2\sylhet_dist_00_20220724_44249.tif
# Chip:  1
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/85483e30457517b9666a02e2d65337a6-c29a038e6e86f8ed0998ff5f2027cc62:getPixels
# Please wait ...
# Data downloaded to Z:\media\mule\Projects\NASA\NIP\Data\Raster\Sylhet\Sen1MitchellSingleOrbit\dryBaseV2\sylhet_dist_01_20220724_44249.tif
# Chip:  2
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/c66f0d5bc5de0e6a097bd15a1e636a42-18801875d9d44bfaaeac6f8a30a41375:getPixels
# Please wait ...
# Data downloaded to Z:\media\mule\Projects\NASA\NIP\Data\Raster\Sylhet\Sen1MitchellSingleOrbit\dryBaseV2\sylhet_dist_02_20220724_44249.tif
# Chip:  3
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/47783b24315ab88cc9700dc08cab7e8c-ffe996538744dc10c7229b330e596a39:getPixels
# Please wait ...
# Data downloaded to Z:\media\mule\Projects\NASA\NIP\Data\Raster\Sylhet\Sen1MitchellSingleOrbit\dryBaseV2\sylhet_dist_03_20220724_44249.tif
# Chip:  4
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/9eb5cb6b044e23bbff7989f8ac4df4ef-4bb18057d6017873855da70c3e53eef5:getPixels
# Please wait ...
# Data downloaded to Z:\media\mule\Projects\NASA\NIP\Data\Raster\Sylhet\Sen1MitchellSingleOrbit\dryBaseV2\sylhet_dist_04_20220724_44249.tif
# Chip:  5
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/1d244079260f0fe44b2390a7201d4846-207dcaac49f08ffffcf90b7db183e5ba:getPixels
# Please wait ...
# Data downloaded to Z:\media\mule\Projects\NASA\NIP\Data\Raster\Sylhet\Sen1MitchellSingleOrbit\dryBaseV2\sylhet_dist_05_20220724_44249.tif
# Chip:  6
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/e6adbef1367b4152ccc03db8d70d6b65-991883b096c5d57f72b51060790cd4e0:getPixels
# Please wait ...
# Data downloaded to Z:\media\mule\Projects\NASA\NIP\Data\Raster\Sylhet\Sen1MitchellSingleOrbit\dryBaseV2\sylhet_dist_06_20220724_44249.tif
# Chip:  7
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/f41662772c8d9280b67f9effc1635a6b-633c6d08649d4cacaa9dfd874d4dccec:getPixels
# Please wait ...
# Data downloaded to Z:\media\mule\Projects\NASA\NIP\Data\Raster\Sylhet\Sen1MitchellSingleOrbit\dryBaseV2\sylhet_dist_07_20220724_44249.tif
# Chip:  8
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/738924e6d5625681516f1c30fec77b0a-955d25993ab5f60d328bda9476633841:getPixels
# Please wait ...
# Data downloaded to Z:\media\mule\Projects\NASA\NIP\Data\Raster\Sylhet\Sen1MitchellSingleOrbit\dryBaseV2\sylhet_dist_08_20220724_44249.tif
# Chip:  9
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/f7edfb9946ace8f1e1c6baa03e37947b-2d11b567ddf5fa3de75a4817a24c6518:getPixels
# Please wait ...
# Data downloaded to Z:\media\mule\Projects\NASA\NIP\Data\Raster\Sylhet\Sen1MitchellSingleOrbit\dryBaseV2\sylhet_dist_09_20220724_44249.tif
# Chip:  10
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/df24b59665f8c315ff7bf569bd1e934e-3cc19767193f58ec74ce3d120560f01e:getPixels
# Please wait ...
# Data downloaded to Z:\media\mule\Projects\NASA\NIP\Data\Raster\Sylhet\Sen1MitchellSingleOrbit\dryBaseV2\sylhet_dist_10_20220724_44249.tif
# Chip:  11
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/f55b85129dbdf3bed701160c80795180-715fdba3f73fe517717c06bd45d0a177:getPixels
# Please wait ...
# Data downloaded to Z:\media\mule\Projects\NASA\NIP\Data\Raster\Sylhet\Sen1MitchellSingleOrbit\dryBaseV2\sylhet_dist_11_20220724_44249.tif
# Chip:  12
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/d84a7b78b56b1b967cfa31bc88a10a7d-72a442021902dcf59ba50926cf9c5cb7:getPixels
# Please wait ...
# Data downloaded to Z:\media\mule\Projects\NASA\NIP\Data\Raster\Sylhet\Sen1MitchellSingleOrbit\dryBaseV2\sylhet_dist_12_20220724_44249.tif
# Chip:  13
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/f2a71485237922bd11987b111dbd41ba-bd1326fc4543e05dabe1be964c085f8c:getPixels
# Please wait ...
# Data downloaded to Z:\media\mule\Projects\NASA\NIP\Data\Raster\Sylhet\Sen1MitchellSingleOrbit\dryBaseV2\sylhet_dist_13_20220724_44249.tif
# Chip:  14
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/ed2425483e8dbd3a712b0536f68655b6-37f405c37f21292074c4c1a262efea4c:getPixels
# Please wait ...
# Data downloaded to Z:\media\mule\Projects\NASA\NIP\Data\Raster\Sylhet\Sen1MitchellSingleOrbit\dryBaseV2\sylhet_dist_14_20220724_44249.tif
# Chip:  15
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/4f8bffcd35b8a143300297bf0095f916-a0b0ec71c3e3ea05a9153d8cf6ec61b9:getPixels
# Please wait ...
# ...
# Chip:  26
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/21869530eb601f9906a27862ad1fc618-e518e187b5009a35ba7427f227af7838:getPixels
# Please wait ...
# Data downloaded to Z:\media\mule\Projects\NASA\NIP\Data\Raster\Sylhet\Sen1MitchellSingleOrbit\dryBaseV2\sylhet_dist_26_20220829_44774.tif
# Chip:  27
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/0005aaab90eca0aea2bfb46acd5341c3-d17d82ef435a6bc9035333c96d8b161a:getPixels
# Please wait ...
# Data downloaded to Z:\media\mule\Projects\NASA\NIP\Data\Raster\Sylhet\Sen1MitchellSingleOrbit\dryBaseV2\sylhet_dist_27_20220829_44774.tif
# Chip:  28
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/bc17cb1ffbbbdb5624d33f5192a85ac1-bbf8339c3e5b7e3dee3d7d51b896ebf2:getPixels
# Please wait ...
# Data downloaded to Z:\media\mule\Projects\NASA\NIP\Data\Raster\Sylhet\Sen1MitchellSingleOrbit\dryBaseV2\sylhet_dist_28_20220829_44774.tif
# Chip:  29
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/5a7ffec2d9be00b425f12c6a47acb1cb-9abb34737f0631a34134cb517260a96b:getPixels
# Please wait ...
# Data downloaded to Z:\media\mule\Projects\NASA\NIP\Data\Raster\Sylhet\Sen1MitchellSingleOrbit\dryBaseV2\sylhet_dist_29_20220829_44774.tif
# Chip:  30
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/b9d159c644e7145d1c66d836968cfe29-6022b76360a2157c555c9b76403e2c75:getPixels
# Please wait ...
# Data downloaded to Z:\media\mule\Projects\NASA\NIP\Data\Raster\Sylhet\Sen1MitchellSingleOrbit\dryBaseV2\sylhet_dist_30_20220829_44774.tif
# Chip:  31
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/6b2667c520b1305b30cd5ebb49760442-44f681492571201a054593849762c8d2:getPixels
# Please wait ...
# Data downloaded to Z:\media\mule\Projects\NASA\NIP\Data\Raster\Sylhet\Sen1MitchellSingleOrbit\dryBaseV2\sylhet_dist_31_20220829_44774.tif
# Chip:  32
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/777330a3104b75133374e11d0377f112-b11543bdb2b532c11cbf58250a8f142d:getPixels
# Please wait ...
# Data downloaded to Z:\media\mule\Projects\NASA\NIP\Data\Raster\Sylhet\Sen1MitchellSingleOrbit\dryBaseV2\sylhet_dist_32_20220829_44774.tif
# Chip:  33
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/825bf5f8f3aea4c491d1d959fbb8ffe6-1626b4a9e97841e035ec6ed551199eb7:getPixels
# Please wait ...
# Data downloaded to Z:\media\mule\Projects\NASA\NIP\Data\Raster\Sylhet\Sen1MitchellSingleOrbit\dryBaseV2\sylhet_dist_33_20220829_44774.tif
# Chip:  34
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/eca589dbd613b600ecb860455b4e378c-65dc319ad68930939c99924ee6a2290d:getPixels
# Please wait ...
# Data downloaded to Z:\media\mule\Projects\NASA\NIP\Data\Raster\Sylhet\Sen1MitchellSingleOrbit\dryBaseV2\sylhet_dist_34_20220829_44774.tif
# Chip:  35
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/bdfa28c9b3929c4291d5fd370e46b7be-46db03c5e8f0f417f444ae2a3aff59ea:getPixels
# Please wait ...
# Data downloaded to Z:\media\mule\Projects\NASA\NIP\Data\Raster\Sylhet\Sen1MitchellSingleOrbit\dryBaseV2\sylhet_dist_35_20220829_44774.tif
# Chip:  36
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/e55c55e0564a2bbcbf2791e5db3cb93e-f65785c0cef9f0fa375865a32883084f:getPixels
# Please wait ...
# Data downloaded to Z:\media\mule\Projects\NASA\NIP\Data\Raster\Sylhet\Sen1MitchellSingleOrbit\dryBaseV2\sylhet_dist_36_20220829_44774.tif
# Chip:  37
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/900122a97f0bf425ed0e81dfdd466ac1-d5e69b4db5c440e2f03607080a50c0e1:getPixels
# Please wait ...
# Data downloaded to Z:\media\mule\Projects\NASA\NIP\Data\Raster\Sylhet\Sen1MitchellSingleOrbit\dryBaseV2\sylhet_dist_37_20220829_44774.tif
# Chip:  38
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/b837ec719a5427350403fb96b36ec958-e181aa3e7b23bd47c03263a46a33a392:getPixels
# Please wait ...
# Data downloaded to Z:\media\mule\Projects\NASA\NIP\Data\Raster\Sylhet\Sen1MitchellSingleOrbit\dryBaseV2\sylhet_dist_38_20220829_44774.tif
# Chip:  39
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/d9985864cb020ebaeba1580695ea1f13-997e011c3dafe5af64954ebfdc260f64:getPixels
# Please wait ...
# Data downloaded to Z:\media\mule\Projects\NASA\NIP\Data\Raster\Sylhet\Sen1MitchellSingleOrbit\dryBaseV2\sylhet_dist_39_20220829_44774.tif
# Chip:  40
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/b0bb7d04288e3c7b0f03d67a30ad8fcf-8b8d1123573db4b574bf99dbaaadff49:getPixels
# Please wait ...
# Data downloaded to Z:\media\mule\Projects\NASA\NIP\Data\Raster\Sylhet\Sen1MitchellSingleOrbit\dryBaseV2\sylhet_dist_40_20220829_44774.tif
# Chip:  41
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/b3604b9f334501fc1e7079084720a6d5-6aba262e4c818dc4ef75e5b25868b77b:getPixels
# Please wait ...
# Data downloaded to Z:\media\mule\Projects\NASA\NIP\Data\Raster\Sylhet\Sen1MitchellSingleOrbit\dryBaseV2\sylhet_dist_41_20220829_44774.tif
# Chip:  42
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/3c523cb0bbaf87f25224bcfc5492fe2e-f81b8cf70f54e1df2761f6d37ba01b03:getPixels
# Please wait ...
# Data downloaded to Z:\media\mule\Projects\NASA\NIP\Data\Raster\Sylhet\Sen1MitchellSingleOrbit\dryBaseV2\sylhet_dist_42_20220829_44774.tif
# Chip:  43
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/2a3a1b5ae7214e5c4d0c30c8acd0d4d4-24d4f6dd0f13c6b91b2d7414d9dcde8a:getPixels
# Please wait ...
# Data downloaded to Z:\media\mule\Projects\NASA\NIP\Data\Raster\Sylhet\Sen1MitchellSingleOrbit\dryBaseV2\sylhet_dist_43_20220829_44774.tif
# Chip:  44
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/107f2ec9baa54c059673f83cfe1ac999-0b371708291b0dec52b401074ec4ca92:getPixels
# Please wait ...
# Data downloaded to Z:\media\mule\Projects\NASA\NIP\Data\Raster\Sylhet\Sen1MitchellSingleOrbit\dryBaseV2\sylhet_dist_44_20220829_44774.tif
# Chip:  45
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/cd6ba57d2b4078414f0a27fbcf760dce-c2ce63ddafa3394a3859499afbb3cdb4:getPixels
# Please wait ...
# Data downloaded to Z:\media\mule\Projects\NASA\NIP\Data\Raster\Sylhet\Sen1MitchellSingleOrbit\dryBaseV2\sylhet_dist_45_20220829_44774.tif
# Chip:  46
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/7fbbc5cf349864406748f3378946a5f6-63e49a3d82d95a1dc51903c09f6865fd:getPixels
# Please wait ...
# Data downloaded to Z:\media\mule\Projects\NASA\NIP\Data\Raster\Sylhet\Sen1MitchellSingleOrbit\dryBaseV2\sylhet_dist_46_20220829_44774.tif
# Chip:  47
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/2dccc2ea40ea7fd1beec2ebcbcf301af-b104992d557d7b6387c70ea88330d2a2:getPixels
# Please wait ...
# Data downloaded to Z:\media\mule\Projects\NASA\NIP\Data\Raster\Sylhet\Sen1MitchellSingleOrbit\dryBaseV2\sylhet_dist_47_20220829_44774.tif
# Chip:  48
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/61a3f03119b86c429c2061c3d391a8d0-1eef3353271a6aa85b20f3c5479d2d5f:getPixels
# Please wait ...
# Data downloaded to Z:\media\mule\Projects\NASA\NIP\Data\Raster\Sylhet\Sen1MitchellSingleOrbit\dryBaseV2\sylhet_dist_48_20220829_44774.tif
# Chip:  49
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/91f92f19dd44c819b0702b3365e224e8-f028bef775d521b857d18cb81932e72b:getPixels
# Please wait ...
# Data downloaded to Z:\media\mule\Projects\NASA\NIP\Data\Raster\Sylhet\Sen1MitchellSingleOrbit\dryBaseV2\sylhet_dist_49_20220829_44774.tif
# Chip:  50
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/82ed0ef216dc41ed00c28c42aee9e18e-b4ffb6b2be543addcd60473379a4a0cc:getPixels
# Please wait ...
# Data downloaded to Z:\media\mule\Projects\NASA\NIP\Data\Raster\Sylhet\Sen1MitchellSingleOrbit\dryBaseV2\sylhet_dist_50_20220829_44774.tif
# Chip:  51
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/07878addde7a7dbe21e78f225151c473-6bacfd128c46bd918a210e32386ccbc4:getPixels
# Please wait ...
# Data downloaded to Z:\media\mule\Projects\NASA\NIP\Data\Raster\Sylhet\Sen1MitchellSingleOrbit\dryBaseV2\sylhet_dist_51_20220829_44774.tif
# Chip:  52
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/8944918d18bf12941f3af913f33c2048-8ba954bf2a9ea78aaa4eccce80bc742f:getPixels
# Please wait ...
# Data downloaded to Z:\media\mule\Projects\NASA\NIP\Data\Raster\Sylhet\Sen1MitchellSingleOrbit\dryBaseV2\sylhet_dist_52_20220829_44774.tif
# Chip:  53
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/525bae53a4a8b9c04fbcfef9aa4f309d-9d92d67014bd24aa76890d5d594547af:getPixels
# Please wait ...
# Data downloaded to Z:\media\mule\Projects\NASA\NIP\Data\Raster\Sylhet\Sen1MitchellSingleOrbit\dryBaseV2\sylhet_dist_53_20220829_44774.tif
# Chip:  54
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/aeb3de1bbd918c5619e2375c6b99189f-654fafcd41dc5d9eba509bc4cf97a488:getPixels
# Please wait ...
# Data downloaded to Z:\media\mule\Projects\NASA\NIP\Data\Raster\Sylhet\Sen1MitchellSingleOrbit\dryBaseV2\sylhet_dist_54_20220829_44774.tif
# Chip:  55
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/d9d69517a9edfc7bc3b27f0581e55736-1575086f4783fa1b55649737bcc37224:getPixels
# Please wait ...
# Data downloaded to Z:\media\mule\Projects\NASA\NIP\Data\Raster\Sylhet\Sen1MitchellSingleOrbit\dryBaseV2\sylhet_dist_55_20220829_44774.tif
# Chip:  56
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/2a38971c1fbc7e71826610e31245a494-474c8091b4dd42e2e785382b9149a3a8:getPixels
# Please wait ...
# Data downloaded to Z:\media\mule\Projects\NASA\NIP\Data\Raster\Sylhet\Sen1MitchellSingleOrbit\dryBaseV2\sylhet_dist_56_20220829_44774.tif
# Chip:  57
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/634cffcfc75ded6e9cb64ffe3d2d521c-2fdc50bd8579bf0743479ee1bce82e5e:getPixels
# Please wait ...
# Data downloaded to Z:\media\mule\Projects\NASA\NIP\Data\Raster\Sylhet\Sen1MitchellSingleOrbit\dryBaseV2\sylhet_dist_57_20220829_44774.tif
# Chip:  58
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/1a8f16cefa30c56bab1cb85fbed11fcf-51182b696b1aa5c7b60d367e9c141901:getPixels
# Please wait ...
# Data downloaded to Z:\media\mule\Projects\NASA\NIP\Data\Raster\Sylhet\Sen1MitchellSingleOrbit\dryBaseV2\sylhet_dist_58_20220829_44774.tif
# Chip:  59
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/c1d071be7d350fb1fde50943b4bc97fa-22c154bd852977b8268c066843a2724b:getPixels
# Please wait ...
# Data downloaded to Z:\media\mule\Projects\NASA\NIP\Data\Raster\Sylhet\Sen1MitchellSingleOrbit\dryBaseV2\sylhet_dist_59_20220829_44774.tif
# Chip:  60
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/729e1d162f81172d0cefab3b6b077710-9232a9b5cbd54f9aa793952fc7d0f9fc:getPixels
# Please wait ...
# Data downloaded to Z:\media\mule\Projects\NASA\NIP\Data\Raster\Sylhet\Sen1MitchellSingleOrbit\dryBaseV2\sylhet_dist_60_20220829_44774.tif
# Chip:  61
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/74f7145fa593559c99be6d2aa9843af4-fdb87dc173105a840b6cbd971a5c4487:getPixels
# Please wait ...
# Data downloaded to Z:\media\mule\Projects\NASA\NIP\Data\Raster\Sylhet\Sen1MitchellSingleOrbit\dryBaseV2\sylhet_dist_61_20220829_44774.tif
# Chip:  62
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/eb4e5e5051c2234b5a65e81de28a2a01-ebd9bd595c099788010203e1e531d37f:getPixels
# Please wait ...
# Data downloaded to Z:\media\mule\Projects\NASA\NIP\Data\Raster\Sylhet\Sen1MitchellSingleOrbit\dryBaseV2\sylhet_dist_62_20220829_44774.tif
# Chip:  63
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/e103c40a123ae62c526e002f054e42c3-8ff33b26c6eb397bc8f969ff269acb4a:getPixels
# Please wait ...
# Data downloaded to Z:\media\mule\Projects\NASA\NIP\Data\Raster\Sylhet\Sen1MitchellSingleOrbit\dryBaseV2\sylhet_dist_63_20220829_44774.tif
# Chip:  64
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/c20d81380dd2a62225cfdb901b2550be-faf113fd8befe0c809c45454cf6e6f68:getPixels
# Please wait ...
# Data downloaded to Z:\media\mule\Projects\NASA\NIP\Data\Raster\Sylhet\Sen1MitchellSingleOrbit\dryBaseV2\sylhet_dist_64_20220829_44774.tif
# Chip:  65
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/96a4d38a252608cedc264cfd4fd66bb1-ffc4a2d7ec238d14fd29cac108aae0b8:getPixels
# Please wait ...
# Data downloaded to Z:\media\mule\Projects\NASA\NIP\Data\Raster\Sylhet\Sen1MitchellSingleOrbit\dryBaseV2\sylhet_dist_65_20220829_44774.tif
# Chip:  66
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/d795d804b1d81718b8d376d9e05d692a-e517724acbe850bd1ee7f6ee62fbd76e:getPixels
# Please wait ...
# Data downloaded to Z:\media\mule\Projects\NASA\NIP\Data\Raster\Sylhet\Sen1MitchellSingleOrbit\dryBaseV2\sylhet_dist_66_20220829_44774.tif
# Chip:  67
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/018a7d6e0ce2ce3dd3a31216bbba9c28-a3c03cdb19801d44a16e265d45fc8d5b:getPixels
# Please wait ...
# Data downloaded to Z:\media\mule\Projects\NASA\NIP\Data\Raster\Sylhet\Sen1MitchellSingleOrbit\dryBaseV2\sylhet_dist_67_20220829_44774.tif
# Chip:  68
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/c55ee42caad2b46752bf8f8aa249abfd-b00f653077233911d6292cf62be35569:getPixels
# Please wait ...
# Data downloaded to Z:\media\mule\Projects\NASA\NIP\Data\Raster\Sylhet\Sen1MitchellSingleOrbit\dryBaseV2\sylhet_dist_68_20220829_44774.tif
# Chip:  69
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/baf1d81bc356ef624248561d64811b09-6ec356e2617ea1ae71a4880fe83f0a9c:getPixels
# Please wait ...
# Data downloaded to Z:\media\mule\Projects\NASA\NIP\Data\Raster\Sylhet\Sen1MitchellSingleOrbit\dryBaseV2\sylhet_dist_69_20220829_44774.tif

# %%
def downloadTile(j, i, grid_size, grid_list, roi_name, imageDate, orbitNumber, outputPath, baseStart, baseEnd, scale, proj, fileList):
    chip_id = range(grid_size)[j]
    chip = ee.Feature(grid_list.get(chip_id)).geometry()
    print('Chip: ', chip_id)

    # Check if tif has already been created before, if so skip
    flood_map_image_path = roi_name + '_' + '{:0>2}'.format(chip_id) + '_' + str(pd.to_datetime(imageDate, unit='ms').strftime("%Y%m%d")) + '_' + str(orbitNumber)
    if flood_map_image_path in fileList:
        print('Already Exists')
        return
    
    flood_map_image_path += '.tif'

    # Run the flood map image function for the given orbitNumber, date and chip
    flood_map_image = dvSOFM.getGTImageSingleOrbit(chip, baseStart, baseEnd, orbitNumber, imageDate)

    # Export the output flood map image
    #geemap.download_ee_image(flood_map_image, outputPath/flood_map_image_path, scale=scale, crs=proj['crs'])# ERROR "partially initialized module 'rasterio' has no attribute '_loading' (most likely due to a circular import)"
    geemap.ee_export_image(flood_map_image, outputPath/flood_map_image_path, scale=scale, crs=proj['crs'], region=chip, file_per_band=False)

# %%
# Loop over each orbit number and chip and apply the surface water mapping algorithm
fileList = ExportHelper.getFileList(outputPath)
for i in range(0, len(orbitNumber_start)):
    orbitNumber = orbitNumber_start[i]
    imageDate = dates[i]
    print('Orbit: ', orbitNumber, '. Date: ', pd.to_datetime(imageDate, unit='ms').strftime("%Y%m%d"))
    if __name__ ==  '__main__': 
        with multiprocessing.Pool(2) as pool:
            pool.map(partial(downloadTile, i, grid_size=grid_size, grid_list=grid_list, roi_name=roi_name, imageDate=imageDate, orbitNumber=orbitNumber, outputPath=outputPath, baseStart=baseStart, baseEnd=baseEnd, scale=scale, proj=proj, fileList=fileList), range(0, grid_size))
    # for j in range(0, grid_size):
# Out:
# Orbit:  43024 . Date:  20220501

# %% [markdown]
# *** NOT USED - originally tried without chipping but file sizes were too big to export with geemap

# %%
#chip_ids = [item['id'] for item in grid.getInfo()['features']]#['id']
#chip_ids_simple = list(range(grid_size))

# %%
# Get the unique orbit numbers for looping over
orbitNumber_start_unique = np.unique(orbitNumber_start)

# Define the start and end dates for the dry baseline
baseStart = '2018-10-28' 
baseEnd = '2018-12-11'

# Provide name for the ROI for naming the exported files
roi_name = 'sylhet_dist'

# Create the output folder for saving the exported files
rootPath = Path('Z:/media/mule/Projects/NASA/NIP/Data/Raster/Sylhet/')
outputPath = rootPath/'Sen1MitchellSingleOrbit'
outputPath.mkdir(exist_ok=True)

# Loop over each orbit number and apply the surface water mapping algorithm
for i in range(0, len(orbitNumber_start_unique)):
    orbitNumber = orbitNumber_start_unique[i]
    imageDate = dates[i]
    #print(orbitNumber_start_i)
    
    # Run the flood map image function
    flood_map_image = dvSOFM.getGTImageSingleOrbit(roi_upa.first().geometry(), baseStart, baseEnd, orbitNumber, imageDate)

    # Export the output flood map image
    flood_map_image_path = roi_name + '_' + str(pd.to_datetime(imageDate, unit='ms').strftime("%Y%m%d")) + '_' + str(orbitNumber) + '.tif'
    #geemap.download_ee_image(flood_map_image, outputPath/flood_map_image_path, scale=scale, crs=proj['crs'])# ERROR "partially initialized module 'rasterio' has no attribute '_loading' (most likely due to a circular import)"
    geemap.ee_export_image(flood_map_image, outputPath/flood_map_image_path, scale=scale, crs=proj['crs'], region=roi_upa.first().geometry(), file_per_band=False)
    #An error occurred while downloading.
    #Total request size (51039144 bytes) must be less than or equal to 50331648 bytes.
